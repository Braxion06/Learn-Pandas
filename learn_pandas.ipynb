# %% [markdown]
# ## Welcome to the notebook
#
# The purpose of this notebook is to learn the pandas library in a relatable way

# %% [markdown]
# First we need to import the necessary libraries for the notebook, in this case will be only pandas

# %%
import pandas as pd

# %% [markdown]
# ## The series object

# %% [markdown]
# The pandas series object is like an array or a list but in the pandas library

# %%
se = pd.Series([10, 20, 30, 40, 50, 60, 70, 80, 90])
se
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# dtype: int64

# %% [markdown]
# These values do not have a context, let's name the series

# %%
se.name = 'amounts'
se
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# Name: amounts, dtype: int64

# %% [markdown]
# We can check its type

# %%
se.dtype
# Out:
# dtype('int64')

# %% [markdown]
# And its values

# %%
se.values
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90], dtype=int64)

# %% [markdown]
# The series object has an index just like a numpy array, because the series is built on top of an actual numpy array

# %%
se
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# 6    70
# 7    80
# 8    90
# Name: amounts, dtype: int64

# %% [markdown]
# Filtering: using index

# %%
se[0]
# Out:
# 10

# %%
se[5]
# Out:
# 60

# %% [markdown]
# We can check the indexes of the series

# %%
se.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %% [markdown]
# But we can also **change** the indexes

# %%
se.index = ['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth', 'Seventh', 'Eighth', 'Ninth'] 
se.index
# Out:
# Index(['First', 'Second', 'Thrid', 'Fourth', 'Fifth', 'Sixth', 'Seventh',
#        'Eighth', 'Ninth'],
#       dtype='object')

# %% [markdown]
# Now let's print the series after the changes

# %%
se
# Out:
# First      10
# Second     20
# Thrid      30
# Fourth     40
# Fifth      50
# Sixth      60
# Seventh    70
# Eighth     80
# Ninth      90
# Name: amounts, dtype: int64

# %% [markdown]
# What if we want to streamline the process, creating the series with its indexes, just like a dictionary

# %%
# Dictionary
se_v2 = {'Blue': 10, 'Red': 40, 'Black': 200}
se_v2
# Out:
# {'Blue': 10, 'Red': 40, 'Black': 200}

# %%
# Series
se_v3 = pd.Series({'Blue': 10, 'Red': 40, 'Black': 200})
se_v3
# Out:
# Blue      10
# Red       40
# Black    200
# dtype: int64

# %% [markdown]
# Let's streamline the process even more by passing through the name of the series

# %%
se_v3 = pd.Series({'Blue': 10, 'Red': 40, 'Black': 200}, name='Series_name_version_3')
se_v3
# Out:
# Blue      10
# Red       40
# Black    200
# Name: Series_name_version_3, dtype: int64

# %% [markdown]
# Another way to do it:

# %%
se_v4 = pd.Series(
    [100, 200, 300, 250, 500], 
    index=['Pants#1261', 'Shirt#45', 'Belt#5', 'Glasses#29', 'Shoes#9'],
    name='Shopping Series')
se_v4
# Out:
# Pants#1261    100
# Shirt#45      200
# Belt#5        300
# Glasses#29    250
# Shoes#9       500
# Name: Shopping Series, dtype: int64

# %% [markdown]
# If we changed the indexes of our series that means we can use them to filter

# %%
se_v4['Pants#1261']
# Out:
# 100

# %%
se_v4['Shoes#9']
# Out:
# 500

# %% [markdown]
# Mutliple index filtering

# %%
se_v4[['Glasses#29', 'Belt#5']]
# Out:
# Glasses#29    250
# Belt#5        300
# Name: Shopping Series, dtype: int64

# %% [markdown]
# We can still filter using the regular indexes [0, 1, 2 ...] using the method .iloc

# %%
se_v4[0]
# Out:
# 100

# %%
se_v4.iloc[-1]
# Out:
# 500

# %% [markdown]
# We need to take into account that filtering in pandas works different than filtering in normal python.
#
# In Pandas the upper limit is included whereas in python isn't

# %%
se_v4
# Out:
# Pants#1261    100
# Shirt#45      200
# Belt#5        300
# Glasses#29    250
# Shoes#9       500
# Name: Shopping Series, dtype: int64

# %%
# Pandas
se_v4['Shirt#45':'Glasses#29']
# Out:
# Shirt#45      200
# Belt#5        300
# Glasses#29    250
# Name: Shopping Series, dtype: int64

# %% [markdown]
# Using Python Filtering

# %%
# Using Python filtering
se_v4.iloc[0:2]
# Out:
# Pants#1261    100
# Shirt#45      200
# Name: Shopping Series, dtype: int64

# %% [markdown]
# Using Pandas Filtering

# %%
# Using Pandas Filtering
se_v4['Pants#1261':'Belt#5']
# Out:
# Pants#1261    100
# Shirt#45      200
# Belt#5        300
# Name: Shopping Series, dtype: int64

# %% [markdown]
# Conditional operations in pandas series

# %%
se_v4 > 150
# Out:
# Pants#1261    False
# Shirt#45       True
# Belt#5         True
# Glasses#29     True
# Shoes#9        True
# Name: Shopping Series, dtype: bool

# %% [markdown]
# Outputting a boolean Series

# %%
se_v4 > se_v4.mean()
# Out:
# Pants#1261    False
# Shirt#45      False
# Belt#5         True
# Glasses#29    False
# Shoes#9        True
# Name: Shopping Series, dtype: bool

# %% [markdown]
# Outputting a filtered series of the actual values

# %%
se_v4 [se_v4 > se_v4.mean()]
# Out:
# Belt#5     300
# Shoes#9    500
# Name: Shopping Series, dtype: int64

# %%
se_v4.count()
# Out:
# 5

# %% [markdown]
# Mathematical operations

# %%
se_v4 + 10000
# Out:
# Pants#1261    10100
# Shirt#45      10200
# Belt#5        10300
# Glasses#29    10250
# Shoes#9       10500
# Name: Shopping Series, dtype: int64

# %%
se_v4.mean()
# Out:
# 270.0

# %%
se_v4.std()
# Out:
# 148.32396974191326

# %% [markdown]
# ## The dataframe object

# %% [markdown]
# Read CSV file and creating a table-like structure called dataframe

# %%
# Example of reading a file in another folder
# df = pd.read_csv('C:\\Users\\User\\Documents\\Learning\\Python\\Pandas\\pandas-master\\pokemon_data.csv')
df = pd.read_csv('pokemon_data.csv')

# %% [markdown]
# Read excel file

# %%
# df_xlsx = pd.read_excel('D:\\Learning\\Python\\Learning notebooks\\Pandas\\pandas-master\\pokemon_data.xlsx')
df_xlsx = pd.read_excel('pokemon_data.xlsx')

# %% [markdown]
# Show a portition of the data top to bottom, usually the first 5 rows

# %%
df_xlsx.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Read Tabular data, separated by \

# %%
# pd_tab_data = pd.read_csv('D:\\Learning\\Python\\Learning notebooks\\Pandas\\pandas-master\\pokemon_data.txt')
pd_tab_data = pd.read_csv('pokemon_data.txt')

# %%
pd_tab_data.head()
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %% [markdown]
# It shows only one column, let's work this out with the delimiters

# %% [markdown]
# Reload the same data specifying the character used to separate columns

# %%
# pd_tab_data = pd.read_csv('D:\\Learning\\Python\\Learning notebooks\\Pandas\\pandas-master\\pokemon_data.txt', delimiter='\t')
pd_tab_data = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %% [markdown]
# Read the data again

# %%
pd_tab_data.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# The dataframe was created correctly, now let's print it in another way

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 12 columns]

# %% [markdown]
# using print() shows a text based output, but using just head as a single output in a cell shows the dataframe as a table, in a prettier way

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# We can adjust how many rows head() shows

# %%
df.head(20)
# Out:
#      #                       Name Type 1  Type 2  HP  Attack  Defense  \
# 0    1                  Bulbasaur  Grass  Poison  45      49       49
# 1    2                    Ivysaur  Grass  Poison  60      62       63
# 2    3                   Venusaur  Grass  Poison  80      82       83
# 3    3      VenusaurMega Venusaur  Grass  Poison  80     100      123
# 4    4                 Charmander   Fire     NaN  39      52       43
# 5    5                 Charmeleon   Fire     NaN  58      64       58
# 6    6                  Charizard   Fire  Flying  78      84       78
# 7    6  CharizardMega Charizard X   Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y   Fire  Flying  78     104       78
# 9    7                   Squirtle  Water     NaN  44      48       65
# 10   8                  Wartortle  Water     NaN  59      63       80
# 11   9                  Blastoise  Water     NaN  79      83      100
# 12   9    BlastoiseMega Blastoise  Water     NaN  79     103      120
# 13  10                   Caterpie    Bug     NaN  45      30       35
# 14  11                    Metapod    Bug     NaN  50      20       55
# 15  12                 Butterfree    Bug  Flying  60      45       50
# 16  13                     Weedle    Bug  Poison  40      35       30
# 17  14                     Kakuna    Bug  Poison  45      25       50
# 18  15                   Beedrill    Bug  Poison  65      90       40
# 19  15      BeedrillMega Beedrill    Bug  Poison  65     150       40
#
#     Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0        65       65     45           1      False
# 1        80       80     60           1      False
# 2       100      100     80           1      False
# 3       122      120     80           1      False
# 4        60       50     65           1      False
# 5        80       65     80           1      False
# 6       109       85    100           1      False
# 7       130       85    100           1      False
# 8       159      115    100           1      False
# 9        50       64     43           1      False
# 10       65       80     58           1      False
# 11       85      105     78           1      False
# 12      135      115     78           1      False
# 13       20       20     45           1      False
# 14       25       25     30           1      False
# 15       90       80     70           1      False
# 16       20       20     50           1      False
# 17       25       25     35           1      False
# 18       45       80     75           1      False
# 19       15       80    145           1      False

# %% [markdown]
# The Tail() method works just like head(), but its output are the last rows of the dataframe

# %%
df.tail()
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %% [markdown]
# Print the list of columns of a dataframe

# %%
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# we can also use the .columns method

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Print columns of a dataframe

# %%
print(df['Name'])
# Or
print(df.Name)
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# Slice the dataframe into a subset of rows in a specific column

# %%
print(df.Name[0:4])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object

# %% [markdown]
# Print a subset of columns with all its rows

# %%
print(df[['Name','Type 1', 'Type 2', 'HP']])
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %% [markdown]
# Print a subset of rows using its index as a key

# %%
print(df.iloc[4:9])
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
#
#    Sp. Def  Speed  Generation  Legendary
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False
# 7       85    100           1      False
# 8      115    100           1      False

# %% [markdown]
# Just one row as a string

# %%
df.iloc[0,1]
# Out:
# 'Bulbasaur'

# %% [markdown]
# One row with a subset of columns

# %%
df.iloc[0,1:3]
# Out:
# Name      Bulbasaur
# Type 1        Grass
# Name: 0, dtype: object

# %% [markdown]
# Iterate in a dataframe printing using the iterrows() method

# %%
for index, row in df.iterrows():
    print(index, row)
# Out:
# 0 #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
# 1 #                   2
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object
# 2 #                    3
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object
# 3 #                                 3
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# Type 2                       Poison
# HP                               80
# Attack                          100
# Defense                         123
# Sp. Atk                         122
# Sp. Def                         120
# Speed                            80
# Generation                        1
# Legendary                     False
# Name: 3, dtype: object
# 4 #                      4
# Name          Charmander
# Type 1              Fire
# Type 2               NaN
# HP                    39
# Attack                52
# Defense               43
# Sp. Atk               60
# Sp. Def               50
# Speed                 65
# Generation             1
# Legendary          False
# Name: 4, dtype: object
# 5 #                      5
# Name          Charmeleon
# Type 1              Fire
# Type 2               NaN
# HP                    58
# Attack                64
# Defense               58
# Sp. Atk               80
# Sp. Def               65
# Speed                 80
# Generation             1
# Legendary          False
# Name: 5, dtype: object
# 6 #                     6
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed               100
# Generation            1
# Legendary         False
# Name: 6, dtype: object
# 7 #                                     6
# Name          CharizardMega Charizard X
# Type 1                             Fire
# Type 2                           Dragon
# HP                                   78
# Attack                              130
# Defense                             111
# Sp. Atk                             130
# Sp. Def                              85
# Speed                               100
# Generation                            1
# Legendary                         False
# Name: 7, dtype: object
# 8 #                                     6
# Name          CharizardMega Charizard Y
# Type 1                             Fire
# Type 2                           Flying
# HP                                   78
# Attack                              104
# Defense                              78
# Sp. Atk                             159
# Sp. Def                             115
# Speed                               100
# Generation                            1
# Legendary                         False
# Name: 8, dtype: object
# 9 #                    7
# Name          Squirtle
# Type 1           Water
# Type 2             NaN
# HP                  44
# Attack              48
# Defense             65
# Sp. Atk             50
# Sp. Def             64
# Speed               43
# Generation           1
# Legendary        False
# Name: 9, dtype: object
# 10 #                     8
# Name          Wartortle
# Type 1            Water
# Type 2              NaN
# HP                   59
# Attack               63
# Defense              80
# Sp. Atk              65
# Sp. Def              80
# Speed                58
# Generation            1
# Legendary         False
# Name: 10, dtype: object
# 11 #                     9
# Name          Blastoise
# Type 1            Water
# Type 2              NaN
# HP                   79
# Attack               83
# Defense             100
# Sp. Atk              85
# Sp. Def             105
# Speed                78
# Generation            1
# Legendary         False
# Name: 11, dtype: object
# 12 #                                   9
# Name          BlastoiseMega Blastoise
# Type 1                          Water
# Type 2                            NaN
# HP                                 79
# Attack                            103
# Defense                           120
# Sp. Atk                           135
# Sp. Def                           115
# Speed                              78
# Generation                          1
# Legendary                       False
# Name: 12, dtype: object
# 13 #                   10
# Name          Caterpie
# Type 1             Bug
# Type 2             NaN
# HP                  45
# Attack              30
# Defense             35
# Sp. Atk             20
# Sp. Def             20
# Speed               45
# Generation           1
# Legendary        False
# Name: 13, dtype: object
# 14 #                  11
# Name          Metapod
# Type 1            Bug
# Type 2            NaN
# HP                 50
# Attack             20
# Defense            55
# Sp. Atk            25
# Sp. Def            25
# Speed              30
# Generation          1
# Legendary       False
# Name: 14, dtype: object
# 15 #                     12
# Name          Butterfree
# Type 1               Bug
# Type 2            Flying
# HP                    60
# Attack                45
# Defense               50
# Sp. Atk               90
# Sp. Def               80
# Speed                 70
# Generation             1
# Legendary          False
# Name: 15, dtype: object
# 16 #                 13
# Name          Weedle
# Type 1           Bug
# Type 2        Poison
# HP                40
# Attack            35
# Defense           30
# Sp. Atk           20
# Sp. Def           20
# Speed             50
# Generation         1
# Legendary      False
# Name: 16, dtype: object
# 17 #                 14
# Name          Kakuna
# Type 1           Bug
# Type 2        Poison
# HP                45
# Attack            25
# Defense           50
# Sp. Atk           25
# Sp. Def           25
# Speed             35
# Generation         1
# Legendary      False
# Name: 17, dtype: object
# 18 #                   15
# Name          Beedrill
# Type 1             Bug
# Type 2          Poison
# HP                  65
# Attack              90
# Defense             40
# Sp. Atk             45
# Sp. Def             80
# Speed               75
# Generation           1
# Legendary        False
# Name: 18, dtype: object
# 19 #                                15
# Name          BeedrillMega Beedrill
# Type 1                          Bug
# Type 2                       Poison
# HP                               65
# Attack                          150
# Defense                          40
# Sp. Atk                          15
# Sp. Def                          80
# Speed                           145
# Generation                        1
# Legendary                     False
# Name: 19, dtype: object
# 20 #                 16
# Name          Pidgey
# Type 1        Normal
# Type 2        Flying
# HP                40
# Attack            45
# Defense           40
# Sp. Atk           35
# Sp. Def           35
# Speed             56
# Generation         1
# Legendary      False
# Name: 20, dtype: object
# 21 #                    17
# Name          Pidgeotto
# Type 1           Normal
# Type 2           Flying
# HP                   63
# Attack               60
# Defense              55
# Sp. Atk              50
# Sp. Def              50
# Speed                71
# Generation            1
# Legendary         False
# Name: 21, dtype: object
# 22 #                  18
# Name          Pidgeot
# Type 1         Normal
# Type 2         Flying
# HP                 83
# Attack             80
# Defense            75
# Sp. Atk            70
# Sp. Def            70
# Speed             101
# Generation          1
# Legendary       False
# Name: 22, dtype: object
# 23 #                              18
# Name          PidgeotMega Pidgeot
# Type 1                     Normal
# Type 2                     Flying
# HP                             83
# Attack                         80
# Defense                        80
# Sp. Atk                       135
# Sp. Def                        80
# Speed                         121
# Generation                      1
# Legendary                   False
# Name: 23, dtype: object
# 24 #                  19
# Name          Rattata
# Type 1         Normal
# Type 2            NaN
# HP                 30
# Attack             56
# Defense            35
# Sp. Atk            25
# Sp. Def            35
# Speed              72
# Generation          1
# Legendary       False
# Name: 24, dtype: object
# 25 #                   20
# Name          Raticate
# Type 1          Normal
# Type 2             NaN
# HP                  55
# Attack              81
# Defense             60
# Sp. Atk             50
# Sp. Def             70
# Speed               97
# Generation           1
# Legendary        False
# Name: 25, dtype: object
# 26 #                  21
# Name          Spearow
# Type 1         Normal
# Type 2         Flying
# HP                 40
# Attack             60
# Defense            30
# Sp. Atk            31
# Sp. Def            31
# Speed              70
# Generation          1
# Legendary       False
# Name: 26, dtype: object
# 27 #                 22
# Name          Fearow
# Type 1        Normal
# Type 2        Flying
# HP                65
# Attack            90
# Defense           65
# Sp. Atk           61
# Sp. Def           61
# Speed            100
# Generation         1
# Legendary      False
# Name: 27, dtype: object
# 28 #                 23
# Name           Ekans
# Type 1        Poison
# Type 2           NaN
# HP                35
# Attack            60
# Defense           44
# Sp. Atk           40
# Sp. Def           54
# Speed             55
# Generation         1
# Legendary      False
# Name: 28, dtype: object
# 29 #                 24
# Name           Arbok
# Type 1        Poison
# Type 2           NaN
# HP                60
# Attack            85
# Defense           69
# Sp. Atk           65
# Sp. Def           79
# Speed             80
# Generation         1
# Legendary      False
# Name: 29, dtype: object
# 30 #                   25
# Name           Pikachu
# Type 1        Electric
# Type 2             NaN
# HP                  35
# Attack              55
# Defense             40
# Sp. Atk             50
# Sp. Def             50
# Speed               90
# Generation           1
# Legendary        False
# Name: 30, dtype: object
# 31 #                   26
# Name            Raichu
# Type 1        Electric
# Type 2             NaN
# HP                  60
# Attack              90
# Defense             55
# Sp. Atk             90
# Sp. Def             80
# Speed              110
# Generation           1
# Legendary        False
# Name: 31, dtype: object
# 32 #                    27
# Name          Sandshrew
# Type 1           Ground
# Type 2              NaN
# HP                   50
# Attack               75
# Defense              85
# Sp. Atk              20
# Sp. Def              30
# Speed                40
# Generation            1
# Legendary         False
# Name: 32, dtype: object
# 33 #                    28
# Name          Sandslash
# Type 1           Ground
# Type 2              NaN
# HP                   75
# Attack              100
# Defense             110
# Sp. Atk              45
# Sp. Def              55
# Speed                65
# Generation            1
# Legendary         False
# Name: 33, dtype: object
# 34 #                           29
# Name          Nidoran (Female)
# Type 1                  Poison
# Type 2                     NaN
# HP                          55
# Attack                      47
# Defense                     52
# Sp. Atk                     40
# Sp. Def                     40
# Speed                       41
# Generation                   1
# Legendary                False
# Name: 34, dtype: object
# 35 #                   30
# Name          Nidorina
# Type 1          Poison
# Type 2             NaN
# HP                  70
# Attack              62
# Defense             67
# Sp. Atk             55
# Sp. Def             55
# Speed               56
# Generation           1
# Legendary        False
# Name: 35, dtype: object
# 36 #                    31
# Name          Nidoqueen
# Type 1           Poison
# Type 2           Ground
# HP                   90
# Attack               92
# Defense              87
# Sp. Atk              75
# Sp. Def              85
# Speed                76
# Generation            1
# Legendary         False
# Name: 36, dtype: object
# 37 #                         32
# Name          Nidoran (Male)
# Type 1                Poison
# Type 2                   NaN
# HP                        46
# Attack                    57
# Defense                   40
# Sp. Atk                   40
# Sp. Def                   40
# Speed                     50
# Generation                 1
# Legendary              False
# Name: 37, dtype: object
# 38 #                   33
# Name          Nidorino
# Type 1          Poison
# Type 2             NaN
# HP                  61
# Attack              72
# Defense             57
# Sp. Atk             55
# Sp. Def             55
# Speed               65
# Generation           1
# Legendary        False
# Name: 38, dtype: object
# 39 #                   34
# Name          Nidoking
# Type 1          Poison
# Type 2          Ground
# HP                  81
# Attack             102
# Defense             77
# Sp. Atk             85
# Sp. Def             75
# Speed               85
# Generation           1
# Legendary        False
# Name: 39, dtype: object
# 40 #                   35
# Name          Clefairy
# Type 1           Fairy
# Type 2             NaN
# HP                  70
# Attack              45
# Defense             48
# Sp. Atk             60
# Sp. Def             65
# Speed               35
# Generation           1
# Legendary        False
# Name: 40, dtype: object
# 41 #                   36
# Name          Clefable
# Type 1           Fairy
# Type 2             NaN
# HP                  95
# Attack              70
# Defense             73
# Sp. Atk             95
# Sp. Def             90
# Speed               60
# Generation           1
# Legendary        False
# Name: 41, dtype: object
# 42 #                 37
# Name          Vulpix
# Type 1          Fire
# Type 2           NaN
# HP                38
# Attack            41
# Defense           40
# Sp. Atk           50
# Sp. Def           65
# Speed             65
# Generation         1
# Legendary      False
# Name: 42, dtype: object
# 43 #                    38
# Name          Ninetales
# Type 1             Fire
# Type 2              NaN
# HP                   73
# Attack               76
# Defense              75
# Sp. Atk              81
# Sp. Def             100
# Speed               100
# Generation            1
# Legendary         False
# Name: 43, dtype: object
# 44 #                     39
# Name          Jigglypuff
# Type 1            Normal
# Type 2             Fairy
# HP                   115
# Attack                45
# Defense               20
# Sp. Atk               45
# Sp. Def               25
# Speed                 20
# Generation             1
# Legendary          False
# Name: 44, dtype: object
# 45 #                     40
# Name          Wigglytuff
# Type 1            Normal
# Type 2             Fairy
# HP                   140
# Attack                70
# Defense               45
# Sp. Atk               85
# Sp. Def               50
# Speed                 45
# Generation             1
# Legendary          False
# Name: 45, dtype: object
# 46 #                 41
# Name           Zubat
# Type 1        Poison
# Type 2        Flying
# HP                40
# Attack            45
# Defense           35
# Sp. Atk           30
# Sp. Def           40
# Speed             55
# Generation         1
# Legendary      False
# Name: 46, dtype: object
# 47 #                 42
# Name          Golbat
# Type 1        Poison
# Type 2        Flying
# HP                75
# Attack            80
# Defense           70
# Sp. Atk           65
# Sp. Def           75
# Speed             90
# Generation         1
# Legendary      False
# Name: 47, dtype: object
# 48 #                 43
# Name          Oddish
# Type 1         Grass
# Type 2        Poison
# HP                45
# Attack            50
# Defense           55
# Sp. Atk           75
# Sp. Def           65
# Speed             30
# Generation         1
# Legendary      False
# Name: 48, dtype: object
# 49 #                 44
# Name           Gloom
# Type 1         Grass
# Type 2        Poison
# HP                60
# Attack            65
# Defense           70
# Sp. Atk           85
# Sp. Def           75
# Speed             40
# Generation         1
# Legendary      False
# Name: 49, dtype: object
# 50 #                    45
# Name          Vileplume
# Type 1            Grass
# Type 2           Poison
# HP                   75
# Attack               80
# Defense              85
# Sp. Atk             110
# Sp. Def              90
# Speed                50
# Generation            1
# Legendary         False
# Name: 50, dtype: object
# 51 #                46
# Name          Paras
# Type 1          Bug
# Type 2        Grass
# HP               35
# Attack           70
# Defense          55
# Sp. Atk          45
# Sp. Def          55
# Speed            25
# Generation        1
# Legendary     False
# Name: 51, dtype: object
# 52 #                   47
# Name          Parasect
# Type 1             Bug
# Type 2           Grass
# HP                  60
# Attack              95
# Defense             80
# Sp. Atk             60
# Sp. Def             80
# Speed               30
# Generation           1
# Legendary        False
# Name: 52, dtype: object
# 53 #                  48
# Name          Venonat
# Type 1            Bug
# Type 2         Poison
# HP                 60
# Attack             55
# Defense            50
# Sp. Atk            40
# Sp. Def            55
# Speed              45
# Generation          1
# Legendary       False
# Name: 53, dtype: object
# 54 #                   49
# Name          Venomoth
# Type 1             Bug
# Type 2          Poison
# HP                  70
# Attack              65
# Defense             60
# Sp. Atk             90
# Sp. Def             75
# Speed               90
# Generation           1
# Legendary        False
# Name: 54, dtype: object
# 55 #                  50
# Name          Diglett
# Type 1         Ground
# Type 2            NaN
# HP                 10
# Attack             55
# Defense            25
# Sp. Atk            35
# Sp. Def            45
# Speed              95
# Generation          1
# Legendary       False
# Name: 55, dtype: object
# 56 #                  51
# Name          Dugtrio
# Type 1         Ground
# Type 2            NaN
# HP                 35
# Attack             80
# Defense            50
# Sp. Atk            50
# Sp. Def            70
# Speed             120
# Generation          1
# Legendary       False
# Name: 56, dtype: object
# 57 #                 52
# Name          Meowth
# Type 1        Normal
# Type 2           NaN
# HP                40
# Attack            45
# Defense           35
# Sp. Atk           40
# Sp. Def           40
# Speed             90
# Generation         1
# Legendary      False
# Name: 57, dtype: object
# 58 #                  53
# Name          Persian
# Type 1         Normal
# Type 2            NaN
# HP                 65
# Attack             70
# Defense            60
# Sp. Atk            65
# Sp. Def            65
# Speed             115
# Generation          1
# Legendary       False
# Name: 58, dtype: object
# 59 #                  54
# Name          Psyduck
# Type 1          Water
# Type 2            NaN
# HP                 50
# Attack             52
# Defense            48
# Sp. Atk            65
# Sp. Def            50
# Speed              55
# Generation          1
# Legendary       False
# Name: 59, dtype: object
# 60 #                  55
# Name          Golduck
# Type 1          Water
# Type 2            NaN
# HP                 80
# Attack             82
# Defense            78
# Sp. Atk            95
# Sp. Def            80
# Speed              85
# Generation          1
# Legendary       False
# Name: 60, dtype: object
# 61 #                   56
# Name            Mankey
# Type 1        Fighting
# Type 2             NaN
# HP                  40
# Attack              80
# Defense             35
# Sp. Atk             35
# Sp. Def             45
# Speed               70
# Generation           1
# Legendary        False
# Name: 61, dtype: object
# 62 #                   57
# Name          Primeape
# Type 1        Fighting
# Type 2             NaN
# HP                  65
# Attack             105
# Defense             60
# Sp. Atk             60
# Sp. Def             70
# Speed               95
# Generation           1
# Legendary        False
# Name: 62, dtype: object
# 63 #                    58
# Name          Growlithe
# Type 1             Fire
# Type 2              NaN
# HP                   55
# Attack               70
# Defense              45
# Sp. Atk              70
# Sp. Def              50
# Speed                60
# Generation            1
# Legendary         False
# Name: 63, dtype: object
# 64 #                   59
# Name          Arcanine
# Type 1            Fire
# Type 2             NaN
# HP                  90
# Attack             110
# Defense             80
# Sp. Atk            100
# Sp. Def             80
# Speed               95
# Generation           1
# Legendary        False
# Name: 64, dtype: object
# 65 #                  60
# Name          Poliwag
# Type 1          Water
# Type 2            NaN
# HP                 40
# Attack             50
# Defense            40
# Sp. Atk            40
# Sp. Def            40
# Speed              90
# Generation          1
# Legendary       False
# Name: 65, dtype: object
# 66 #                    61
# Name          Poliwhirl
# Type 1            Water
# Type 2              NaN
# HP                   65
# Attack               65
# Defense              65
# Sp. Atk              50
# Sp. Def              50
# Speed                90
# Generation            1
# Legendary         False
# Name: 66, dtype: object
# 67 #                    62
# Name          Poliwrath
# Type 1            Water
# Type 2         Fighting
# HP                   90
# Attack               95
# Defense              95
# Sp. Atk              70
# Sp. Def              90
# Speed                70
# Generation            1
# Legendary         False
# Name: 67, dtype: object
# 68 #                  63
# Name             Abra
# Type 1        Psychic
# Type 2            NaN
# HP                 25
# Attack             20
# Defense            15
# Sp. Atk           105
# Sp. Def            55
# Speed              90
# Generation          1
# Legendary       False
# Name: 68, dtype: object
# 69 #                  64
# Name          Kadabra
# Type 1        Psychic
# Type 2            NaN
# HP                 40
# Attack             35
# Defense            30
# Sp. Atk           120
# Sp. Def            70
# Speed             105
# Generation          1
# Legendary       False
# Name: 69, dtype: object
# 70 #                   65
# Name          Alakazam
# Type 1         Psychic
# Type 2             NaN
# HP                  55
# Attack              50
# Defense             45
# Sp. Atk            135
# Sp. Def             95
# Speed              120
# Generation           1
# Legendary        False
# Name: 70, dtype: object
# 71 #                                65
# Name          AlakazamMega Alakazam
# Type 1                      Psychic
# Type 2                          NaN
# HP                               55
# Attack                           50
# Defense                          65
# Sp. Atk                         175
# Sp. Def                          95
# Speed                           150
# Generation                        1
# Legendary                     False
# Name: 71, dtype: object
# 72 #                   66
# Name            Machop
# Type 1        Fighting
# Type 2             NaN
# HP                  70
# Attack              80
# Defense             50
# Sp. Atk             35
# Sp. Def             35
# Speed               35
# Generation           1
# Legendary        False
# Name: 72, dtype: object
# 73 #                   67
# Name           Machoke
# Type 1        Fighting
# Type 2             NaN
# HP                  80
# Attack             100
# Defense             70
# Sp. Atk             50
# Sp. Def             60
# Speed               45
# Generation           1
# Legendary        False
# Name: 73, dtype: object
# 74 #                   68
# Name           Machamp
# Type 1        Fighting
# Type 2             NaN
# HP                  90
# Attack             130
# Defense             80
# Sp. Atk             65
# Sp. Def             85
# Speed               55
# Generation           1
# Legendary        False
# Name: 74, dtype: object
# 75 #                     69
# Name          Bellsprout
# Type 1             Grass
# Type 2            Poison
# HP                    50
# Attack                75
# Defense               35
# Sp. Atk               70
# Sp. Def               30
# Speed                 40
# Generation             1
# Legendary          False
# Name: 75, dtype: object
# 76 #                     70
# Name          Weepinbell
# Type 1             Grass
# Type 2            Poison
# HP                    65
# Attack                90
# Defense               50
# Sp. Atk               85
# Sp. Def               45
# Speed                 55
# Generation             1
# Legendary          False
# Name: 76, dtype: object
# 77 #                     71
# Name          Victreebel
# Type 1             Grass
# Type 2            Poison
# HP                    80
# Attack               105
# Defense               65
# Sp. Atk              100
# Sp. Def               70
# Speed                 70
# Generation             1
# Legendary          False
# Name: 77, dtype: object
# 78 #                    72
# Name          Tentacool
# Type 1            Water
# Type 2           Poison
# HP                   40
# Attack               40
# Defense              35
# Sp. Atk              50
# Sp. Def             100
# Speed                70
# Generation            1
# Legendary         False
# Name: 78, dtype: object
# 79 #                     73
# Name          Tentacruel
# Type 1             Water
# Type 2            Poison
# HP                    80
# Attack                70
# Defense               65
# Sp. Atk               80
# Sp. Def              120
# Speed                100
# Generation             1
# Legendary          False
# Name: 79, dtype: object
# 80 #                  74
# Name          Geodude
# Type 1           Rock
# Type 2         Ground
# HP                 40
# Attack             80
# Defense           100
# Sp. Atk            30
# Sp. Def            30
# Speed              20
# Generation          1
# Legendary       False
# Name: 80, dtype: object
# 81 #                   75
# Name          Graveler
# Type 1            Rock
# Type 2          Ground
# HP                  55
# Attack              95
# Defense            115
# Sp. Atk             45
# Sp. Def             45
# Speed               35
# Generation           1
# Legendary        False
# Name: 81, dtype: object
# 82 #                 76
# Name           Golem
# Type 1          Rock
# Type 2        Ground
# HP                80
# Attack           120
# Defense          130
# Sp. Atk           55
# Sp. Def           65
# Speed             45
# Generation         1
# Legendary      False
# Name: 82, dtype: object
# 83 #                 77
# Name          Ponyta
# Type 1          Fire
# Type 2           NaN
# HP                50
# Attack            85
# Defense           55
# Sp. Atk           65
# Sp. Def           65
# Speed             90
# Generation         1
# Legendary      False
# Name: 83, dtype: object
# 84 #                   78
# Name          Rapidash
# Type 1            Fire
# Type 2             NaN
# HP                  65
# Attack             100
# Defense             70
# Sp. Atk             80
# Sp. Def             80
# Speed              105
# Generation           1
# Legendary        False
# Name: 84, dtype: object
# 85 #                   79
# Name          Slowpoke
# Type 1           Water
# Type 2         Psychic
# HP                  90
# Attack              65
# Defense             65
# Sp. Atk             40
# Sp. Def             40
# Speed               15
# Generation           1
# Legendary        False
# Name: 85, dtype: object
# 86 #                  80
# Name          Slowbro
# Type 1          Water
# Type 2        Psychic
# HP                 95
# Attack             75
# Defense           110
# Sp. Atk           100
# Sp. Def            80
# Speed              30
# Generation          1
# Legendary       False
# Name: 86, dtype: object
# 87 #                              80
# Name          SlowbroMega Slowbro
# Type 1                      Water
# Type 2                    Psychic
# HP                             95
# Attack                         75
# Defense                       180
# Sp. Atk                       130
# Sp. Def                        80
# Speed                          30
# Generation                      1
# Legendary                   False
# Name: 87, dtype: object
# 88 #                    81
# Name          Magnemite
# Type 1         Electric
# Type 2            Steel
# HP                   25
# Attack               35
# Defense              70
# Sp. Atk              95
# Sp. Def              55
# Speed                45
# Generation            1
# Legendary         False
# Name: 88, dtype: object
# 89 #                   82
# Name          Magneton
# Type 1        Electric
# Type 2           Steel
# HP                  50
# Attack              60
# Defense             95
# Sp. Atk            120
# Sp. Def             70
# Speed               70
# Generation           1
# Legendary        False
# Name: 89, dtype: object
# 90 #                     83
# Name          Farfetch'd
# Type 1            Normal
# Type 2            Flying
# HP                    52
# Attack                65
# Defense               55
# Sp. Atk               58
# Sp. Def               62
# Speed                 60
# Generation             1
# Legendary          False
# Name: 90, dtype: object
# 91 #                 84
# Name           Doduo
# Type 1        Normal
# Type 2        Flying
# HP                35
# Attack            85
# Defense           45
# Sp. Atk           35
# Sp. Def           35
# Speed             75
# Generation         1
# Legendary      False
# Name: 91, dtype: object
# 92 #                 85
# Name          Dodrio
# Type 1        Normal
# Type 2        Flying
# HP                60
# Attack           110
# Defense           70
# Sp. Atk           60
# Sp. Def           60
# Speed            100
# Generation         1
# Legendary      False
# Name: 92, dtype: object
# 93 #                86
# Name           Seel
# Type 1        Water
# Type 2          NaN
# HP               65
# Attack           45
# Defense          55
# Sp. Atk          45
# Sp. Def          70
# Speed            45
# Generation        1
# Legendary     False
# Name: 93, dtype: object
# 94 #                  87
# Name          Dewgong
# Type 1          Water
# Type 2            Ice
# HP                 90
# Attack             70
# Defense            80
# Sp. Atk            70
# Sp. Def            95
# Speed              70
# Generation          1
# Legendary       False
# Name: 94, dtype: object
# 95 #                 88
# Name          Grimer
# Type 1        Poison
# Type 2           NaN
# HP                80
# Attack            80
# Defense           50
# Sp. Atk           40
# Sp. Def           50
# Speed             25
# Generation         1
# Legendary      False
# Name: 95, dtype: object
# 96 #                 89
# Name             Muk
# Type 1        Poison
# Type 2           NaN
# HP               105
# Attack           105
# Defense           75
# Sp. Atk           65
# Sp. Def          100
# Speed             50
# Generation         1
# Legendary      False
# Name: 96, dtype: object
# 97 #                   90
# Name          Shellder
# Type 1           Water
# Type 2             NaN
# HP                  30
# Attack              65
# Defense            100
# Sp. Atk             45
# Sp. Def             25
# Speed               40
# Generation           1
# Legendary        False
# Name: 97, dtype: object
# 98 #                   91
# Name          Cloyster
# Type 1           Water
# Type 2             Ice
# HP                  50
# Attack              95
# Defense            180
# Sp. Atk             85
# Sp. Def             45
# Speed               70
# Generation           1
# Legendary        False
# Name: 98, dtype: object
# 99 #                 92
# Name          Gastly
# Type 1         Ghost
# Type 2        Poison
# HP                30
# Attack            35
# Defense           30
# Sp. Atk          100
# Sp. Def           35
# Speed             80
# Generation         1
# Legendary      False
# Name: 99, dtype: object
# 100 #                  93
# Name          Haunter
# Type 1          Ghost
# Type 2         Poison
# HP                 45
# Attack             50
# Defense            45
# Sp. Atk           115
# Sp. Def            55
# Speed              95
# Generation          1
# Legendary       False
# Name: 100, dtype: object
# 101 #                 94
# Name          Gengar
# Type 1         Ghost
# Type 2        Poison
# HP                60
# Attack            65
# Defense           60
# Sp. Atk          130
# Sp. Def           75
# Speed            110
# Generation         1
# Legendary      False
# Name: 101, dtype: object
# 102 #                            94
# Name          GengarMega Gengar
# Type 1                    Ghost
# Type 2                   Poison
# HP                           60
# Attack                       65
# Defense                      80
# Sp. Atk                     170
# Sp. Def                      95
# Speed                       130
# Generation                    1
# Legendary                 False
# Name: 102, dtype: object
# 103 #                 95
# Name            Onix
# Type 1          Rock
# Type 2        Ground
# HP                35
# Attack            45
# Defense          160
# Sp. Atk           30
# Sp. Def           45
# Speed             70
# Generation         1
# Legendary      False
# Name: 103, dtype: object
# 104 #                  96
# Name          Drowzee
# Type 1        Psychic
# Type 2            NaN
# HP                 60
# Attack             48
# Defense            45
# Sp. Atk            43
# Sp. Def            90
# Speed              42
# Generation          1
# Legendary       False
# Name: 104, dtype: object
# 105 #                  97
# Name            Hypno
# Type 1        Psychic
# Type 2            NaN
# HP                 85
# Attack             73
# Defense            70
# Sp. Atk            73
# Sp. Def           115
# Speed              67
# Generation          1
# Legendary       False
# Name: 105, dtype: object
# 106 #                 98
# Name          Krabby
# Type 1         Water
# Type 2           NaN
# HP                30
# Attack           105
# Defense           90
# Sp. Atk           25
# Sp. Def           25
# Speed             50
# Generation         1
# Legendary      False
# Name: 106, dtype: object
# 107 #                  99
# Name          Kingler
# Type 1          Water
# Type 2            NaN
# HP                 55
# Attack            130
# Defense           115
# Sp. Atk            50
# Sp. Def            50
# Speed              75
# Generation          1
# Legendary       False
# Name: 107, dtype: object
# 108 #                  100
# Name           Voltorb
# Type 1        Electric
# Type 2             NaN
# HP                  40
# Attack              30
# Defense             50
# Sp. Atk             55
# Sp. Def             55
# Speed              100
# Generation           1
# Legendary        False
# Name: 108, dtype: object
# 109 #                   101
# Name          Electrode
# Type 1         Electric
# Type 2              NaN
# HP                   60
# Attack               50
# Defense              70
# Sp. Atk              80
# Sp. Def              80
# Speed               140
# Generation            1
# Legendary         False
# Name: 109, dtype: object
# 110 #                   102
# Name          Exeggcute
# Type 1            Grass
# Type 2          Psychic
# HP                   60
# Attack               40
# Defense              80
# Sp. Atk              60
# Sp. Def              45
# Speed                40
# Generation            1
# Legendary         False
# Name: 110, dtype: object
# 111 #                   103
# Name          Exeggutor
# Type 1            Grass
# Type 2          Psychic
# HP                   95
# Attack               95
# Defense              85
# Sp. Atk             125
# Sp. Def              65
# Speed                55
# Generation            1
# Legendary         False
# Name: 111, dtype: object
# 112 #                104
# Name          Cubone
# Type 1        Ground
# Type 2           NaN
# HP                50
# Attack            50
# Defense           95
# Sp. Atk           40
# Sp. Def           50
# Speed             35
# Generation         1
# Legendary      False
# Name: 112, dtype: object
# 113 #                 105
# Name          Marowak
# Type 1         Ground
# Type 2            NaN
# HP                 60
# Attack             80
# Defense           110
# Sp. Atk            50
# Sp. Def            80
# Speed              45
# Generation          1
# Legendary       False
# Name: 113, dtype: object
# 114 #                   106
# Name          Hitmonlee
# Type 1         Fighting
# Type 2              NaN
# HP                   50
# Attack              120
# Defense              53
# Sp. Atk              35
# Sp. Def             110
# Speed                87
# Generation            1
# Legendary         False
# Name: 114, dtype: object
# 115 #                    107
# Name          Hitmonchan
# Type 1          Fighting
# Type 2               NaN
# HP                    50
# Attack               105
# Defense               79
# Sp. Atk               35
# Sp. Def              110
# Speed                 76
# Generation             1
# Legendary          False
# Name: 115, dtype: object
# 116 #                   108
# Name          Lickitung
# Type 1           Normal
# Type 2              NaN
# HP                   90
# Attack               55
# Defense              75
# Sp. Atk              60
# Sp. Def              75
# Speed                30
# Generation            1
# Legendary         False
# Name: 116, dtype: object
# 117 #                 109
# Name          Koffing
# Type 1         Poison
# Type 2            NaN
# HP                 40
# Attack             65
# Defense            95
# Sp. Atk            60
# Sp. Def            45
# Speed              35
# Generation          1
# Legendary       False
# Name: 117, dtype: object
# 118 #                 110
# Name          Weezing
# Type 1         Poison
# Type 2            NaN
# HP                 65
# Attack             90
# Defense           120
# Sp. Atk            85
# Sp. Def            70
# Speed              60
# Generation          1
# Legendary       False
# Name: 118, dtype: object
# 119 #                 111
# Name          Rhyhorn
# Type 1         Ground
# Type 2           Rock
# HP                 80
# Attack             85
# Defense            95
# Sp. Atk            30
# Sp. Def            30
# Speed              25
# Generation          1
# Legendary       False
# Name: 119, dtype: object
# 120 #                112
# Name          Rhydon
# Type 1        Ground
# Type 2          Rock
# HP               105
# Attack           130
# Defense          120
# Sp. Atk           45
# Sp. Def           45
# Speed             40
# Generation         1
# Legendary      False
# Name: 120, dtype: object
# 121 #                 113
# Name          Chansey
# Type 1         Normal
# Type 2            NaN
# HP                250
# Attack              5
# Defense             5
# Sp. Atk            35
# Sp. Def           105
# Speed              50
# Generation          1
# Legendary       False
# Name: 121, dtype: object
# 122 #                 114
# Name          Tangela
# Type 1          Grass
# Type 2            NaN
# HP                 65
# Attack             55
# Defense           115
# Sp. Atk           100
# Sp. Def            40
# Speed              60
# Generation          1
# Legendary       False
# Name: 122, dtype: object
# 123 #                    115
# Name          Kangaskhan
# Type 1            Normal
# Type 2               NaN
# HP                   105
# Attack                95
# Defense               80
# Sp. Atk               40
# Sp. Def               80
# Speed                 90
# Generation             1
# Legendary          False
# Name: 123, dtype: object
# 124 #                                   115
# Name          KangaskhanMega Kangaskhan
# Type 1                           Normal
# Type 2                              NaN
# HP                                  105
# Attack                              125
# Defense                             100
# Sp. Atk                              60
# Sp. Def                             100
# Speed                               100
# Generation                            1
# Legendary                         False
# Name: 124, dtype: object
# 125 #                116
# Name          Horsea
# Type 1         Water
# Type 2           NaN
# HP                30
# Attack            40
# Defense           70
# Sp. Atk           70
# Sp. Def           25
# Speed             60
# Generation         1
# Legendary      False
# Name: 125, dtype: object
# 126 #                117
# Name          Seadra
# Type 1         Water
# Type 2           NaN
# HP                55
# Attack            65
# Defense           95
# Sp. Atk           95
# Sp. Def           45
# Speed             85
# Generation         1
# Legendary      False
# Name: 126, dtype: object
# 127 #                 118
# Name          Goldeen
# Type 1          Water
# Type 2            NaN
# HP                 45
# Attack             67
# Defense            60
# Sp. Atk            35
# Sp. Def            50
# Speed              63
# Generation          1
# Legendary       False
# Name: 127, dtype: object
# 128 #                 119
# Name          Seaking
# Type 1          Water
# Type 2            NaN
# HP                 80
# Attack             92
# Defense            65
# Sp. Atk            65
# Sp. Def            80
# Speed              68
# Generation          1
# Legendary       False
# Name: 128, dtype: object
# 129 #                120
# Name          Staryu
# Type 1         Water
# Type 2           NaN
# HP                30
# Attack            45
# Defense           55
# Sp. Atk           70
# Sp. Def           55
# Speed             85
# Generation         1
# Legendary      False
# Name: 129, dtype: object
# 130 #                 121
# Name          Starmie
# Type 1          Water
# Type 2        Psychic
# HP                 60
# Attack             75
# Defense            85
# Sp. Atk           100
# Sp. Def            85
# Speed             115
# Generation          1
# Legendary       False
# Name: 130, dtype: object
# 131 #                  122
# Name          Mr. Mime
# Type 1         Psychic
# Type 2           Fairy
# HP                  40
# Attack              45
# Defense             65
# Sp. Atk            100
# Sp. Def            120
# Speed               90
# Generation           1
# Legendary        False
# Name: 131, dtype: object
# 132 #                 123
# Name          Scyther
# Type 1            Bug
# Type 2         Flying
# HP                 70
# Attack            110
# Defense            80
# Sp. Atk            55
# Sp. Def            80
# Speed             105
# Generation          1
# Legendary       False
# Name: 132, dtype: object
# 133 #                 124
# Name             Jynx
# Type 1            Ice
# Type 2        Psychic
# HP                 65
# Attack             50
# Defense            35
# Sp. Atk           115
# Sp. Def            95
# Speed              95
# Generation          1
# Legendary       False
# Name: 133, dtype: object
# 134 #                    125
# Name          Electabuzz
# Type 1          Electric
# Type 2               NaN
# HP                    65
# Attack                83
# Defense               57
# Sp. Atk               95
# Sp. Def               85
# Speed                105
# Generation             1
# Legendary          False
# Name: 134, dtype: object
# 135 #                126
# Name          Magmar
# Type 1          Fire
# Type 2           NaN
# HP                65
# Attack            95
# Defense           57
# Sp. Atk          100
# Sp. Def           85
# Speed             93
# Generation         1
# Legendary      False
# Name: 135, dtype: object
# 136 #                127
# Name          Pinsir
# Type 1           Bug
# Type 2           NaN
# HP                65
# Attack           125
# Defense          100
# Sp. Atk           55
# Sp. Def           70
# Speed             85
# Generation         1
# Legendary      False
# Name: 136, dtype: object
# 137 #                           127
# Name          PinsirMega Pinsir
# Type 1                      Bug
# Type 2                   Flying
# HP                           65
# Attack                      155
# Defense                     120
# Sp. Atk                      65
# Sp. Def                      90
# Speed                       105
# Generation                    1
# Legendary                 False
# Name: 137, dtype: object
# 138 #                128
# Name          Tauros
# Type 1        Normal
# Type 2           NaN
# HP                75
# Attack           100
# Defense           95
# Sp. Atk           40
# Sp. Def           70
# Speed            110
# Generation         1
# Legendary      False
# Name: 138, dtype: object
# 139 #                  129
# Name          Magikarp
# Type 1           Water
# Type 2             NaN
# HP                  20
# Attack              10
# Defense             55
# Sp. Atk             15
# Sp. Def             20
# Speed               80
# Generation           1
# Legendary        False
# Name: 139, dtype: object
# 140 #                  130
# Name          Gyarados
# Type 1           Water
# Type 2          Flying
# HP                  95
# Attack             125
# Defense             79
# Sp. Atk             60
# Sp. Def            100
# Speed               81
# Generation           1
# Legendary        False
# Name: 140, dtype: object
# 141 #                               130
# Name          GyaradosMega Gyarados
# Type 1                        Water
# Type 2                         Dark
# HP                               95
# Attack                          155
# Defense                         109
# Sp. Atk                          70
# Sp. Def                         130
# Speed                            81
# Generation                        1
# Legendary                     False
# Name: 141, dtype: object
# 142 #                131
# Name          Lapras
# Type 1         Water
# Type 2           Ice
# HP               130
# Attack            85
# Defense           80
# Sp. Atk           85
# Sp. Def           95
# Speed             60
# Generation         1
# Legendary      False
# Name: 142, dtype: object
# 143 #                132
# Name           Ditto
# Type 1        Normal
# Type 2           NaN
# HP                48
# Attack            48
# Defense           48
# Sp. Atk           48
# Sp. Def           48
# Speed             48
# Generation         1
# Legendary      False
# Name: 143, dtype: object
# 144 #                133
# Name           Eevee
# Type 1        Normal
# Type 2           NaN
# HP                55
# Attack            55
# Defense           50
# Sp. Atk           45
# Sp. Def           65
# Speed             55
# Generation         1
# Legendary      False
# Name: 144, dtype: object
# 145 #                  134
# Name          Vaporeon
# Type 1           Water
# Type 2             NaN
# HP                 130
# Attack              65
# Defense             60
# Sp. Atk            110
# Sp. Def             95
# Speed               65
# Generation           1
# Legendary        False
# Name: 145, dtype: object
# 146 #                  135
# Name           Jolteon
# Type 1        Electric
# Type 2             NaN
# HP                  65
# Attack              65
# Defense             60
# Sp. Atk            110
# Sp. Def             95
# Speed              130
# Generation           1
# Legendary        False
# Name: 146, dtype: object
# 147 #                 136
# Name          Flareon
# Type 1           Fire
# Type 2            NaN
# HP                 65
# Attack            130
# Defense            60
# Sp. Atk            95
# Sp. Def           110
# Speed              65
# Generation          1
# Legendary       False
# Name: 147, dtype: object
# 148 #                 137
# Name          Porygon
# Type 1         Normal
# Type 2            NaN
# HP                 65
# Attack             60
# Defense            70
# Sp. Atk            85
# Sp. Def            75
# Speed              40
# Generation          1
# Legendary       False
# Name: 148, dtype: object
# 149 #                 138
# Name          Omanyte
# Type 1           Rock
# Type 2          Water
# HP                 35
# Attack             40
# Defense           100
# Sp. Atk            90
# Sp. Def            55
# Speed              35
# Generation          1
# Legendary       False
# Name: 149, dtype: object
# 150 #                 139
# Name          Omastar
# Type 1           Rock
# Type 2          Water
# HP                 70
# Attack             60
# Defense           125
# Sp. Atk           115
# Sp. Def            70
# Speed              55
# Generation          1
# Legendary       False
# Name: 150, dtype: object
# 151 #                140
# Name          Kabuto
# Type 1          Rock
# Type 2         Water
# HP                30
# Attack            80
# Defense           90
# Sp. Atk           55
# Sp. Def           45
# Speed             55
# Generation         1
# Legendary      False
# Name: 151, dtype: object
# 152 #                  141
# Name          Kabutops
# Type 1            Rock
# Type 2           Water
# HP                  60
# Attack             115
# Defense            105
# Sp. Atk             65
# Sp. Def             70
# Speed               80
# Generation           1
# Legendary        False
# Name: 152, dtype: object
# 153 #                    142
# Name          Aerodactyl
# Type 1              Rock
# Type 2            Flying
# HP                    80
# Attack               105
# Defense               65
# Sp. Atk               60
# Sp. Def               75
# Speed                130
# ...
# Type 1           Fairy
# Type 2             NaN
# HP                  78
# Attack              52
# Defense             60
# Sp. Atk             63
# Sp. Def             65
# Speed               23
# Generation           6
# Legendary        False
# Name: 752, dtype: object
# 753 #                    683
# Name          Aromatisse
# Type 1             Fairy
# Type 2               NaN
# HP                   101
# Attack                72
# Defense               72
# Sp. Atk               99
# Sp. Def               89
# Speed                 29
# Generation             6
# Legendary          False
# Name: 753, dtype: object
# 754 #                 684
# Name          Swirlix
# Type 1          Fairy
# Type 2            NaN
# HP                 62
# Attack             48
# Defense            66
# Sp. Atk            59
# Sp. Def            57
# Speed              49
# Generation          6
# Legendary       False
# Name: 754, dtype: object
# 755 #                  685
# Name          Slurpuff
# Type 1           Fairy
# Type 2             NaN
# HP                  82
# Attack              80
# Defense             86
# Sp. Atk             85
# Sp. Def             75
# Speed               72
# Generation           6
# Legendary        False
# Name: 755, dtype: object
# 756 #                 686
# Name            Inkay
# Type 1           Dark
# Type 2        Psychic
# HP                 53
# Attack             54
# Defense            53
# Sp. Atk            37
# Sp. Def            46
# Speed              45
# Generation          6
# Legendary       False
# Name: 756, dtype: object
# 757 #                 687
# Name          Malamar
# Type 1           Dark
# Type 2        Psychic
# HP                 86
# Attack             92
# Defense            88
# Sp. Atk            68
# Sp. Def            75
# Speed              73
# Generation          6
# Legendary       False
# Name: 757, dtype: object
# 758 #                 688
# Name          Binacle
# Type 1           Rock
# Type 2          Water
# HP                 42
# Attack             52
# Defense            67
# Sp. Atk            39
# Sp. Def            56
# Speed              50
# Generation          6
# Legendary       False
# Name: 758, dtype: object
# 759 #                    689
# Name          Barbaracle
# Type 1              Rock
# Type 2             Water
# HP                    72
# Attack               105
# Defense              115
# Sp. Atk               54
# Sp. Def               86
# Speed                 68
# Generation             6
# Legendary          False
# Name: 759, dtype: object
# 760 #                690
# Name          Skrelp
# Type 1        Poison
# Type 2         Water
# HP                50
# Attack            60
# Defense           60
# Sp. Atk           60
# Sp. Def           60
# Speed             30
# Generation         6
# Legendary      False
# Name: 760, dtype: object
# 761 #                  691
# Name          Dragalge
# Type 1          Poison
# Type 2          Dragon
# HP                  65
# Attack              75
# Defense             90
# Sp. Atk             97
# Sp. Def            123
# Speed               44
# Generation           6
# Legendary        False
# Name: 761, dtype: object
# 762 #                   692
# Name          Clauncher
# Type 1            Water
# Type 2              NaN
# HP                   50
# Attack               53
# Defense              62
# Sp. Atk              58
# Sp. Def              63
# Speed                44
# Generation            6
# Legendary         False
# Name: 762, dtype: object
# 763 #                   693
# Name          Clawitzer
# Type 1            Water
# Type 2              NaN
# HP                   71
# Attack               73
# Defense              88
# Sp. Atk             120
# Sp. Def              89
# Speed                59
# Generation            6
# Legendary         False
# Name: 763, dtype: object
# 764 #                    694
# Name          Helioptile
# Type 1          Electric
# Type 2            Normal
# HP                    44
# Attack                38
# Defense               33
# Sp. Atk               61
# Sp. Def               43
# Speed                 70
# Generation             6
# Legendary          False
# Name: 764, dtype: object
# 765 #                   695
# Name          Heliolisk
# Type 1         Electric
# Type 2           Normal
# HP                   62
# Attack               55
# Defense              52
# Sp. Atk             109
# Sp. Def              94
# Speed               109
# Generation            6
# Legendary         False
# Name: 765, dtype: object
# 766 #                696
# Name          Tyrunt
# Type 1          Rock
# Type 2        Dragon
# HP                58
# Attack            89
# Defense           77
# Sp. Atk           45
# Sp. Def           45
# Speed             48
# Generation         6
# Legendary      False
# Name: 766, dtype: object
# 767 #                   697
# Name          Tyrantrum
# Type 1             Rock
# Type 2           Dragon
# HP                   82
# Attack              121
# Defense             119
# Sp. Atk              69
# Sp. Def              59
# Speed                71
# Generation            6
# Legendary         False
# Name: 767, dtype: object
# 768 #                698
# Name          Amaura
# Type 1          Rock
# Type 2           Ice
# HP                77
# Attack            59
# Defense           50
# Sp. Atk           67
# Sp. Def           63
# Speed             46
# Generation         6
# Legendary      False
# Name: 768, dtype: object
# 769 #                 699
# Name          Aurorus
# Type 1           Rock
# Type 2            Ice
# HP                123
# Attack             77
# Defense            72
# Sp. Atk            99
# Sp. Def            92
# Speed              58
# Generation          6
# Legendary       False
# Name: 769, dtype: object
# 770 #                 700
# Name          Sylveon
# Type 1          Fairy
# Type 2            NaN
# HP                 95
# Attack             65
# Defense            65
# Sp. Atk           110
# Sp. Def           130
# Speed              60
# Generation          6
# Legendary       False
# Name: 770, dtype: object
# 771 #                  701
# Name          Hawlucha
# Type 1        Fighting
# Type 2          Flying
# HP                  78
# Attack              92
# Defense             75
# Sp. Atk             74
# Sp. Def             63
# Speed              118
# Generation           6
# Legendary        False
# Name: 771, dtype: object
# 772 #                  702
# Name           Dedenne
# Type 1        Electric
# Type 2           Fairy
# HP                  67
# Attack              58
# Defense             57
# Sp. Atk             81
# Sp. Def             67
# Speed              101
# Generation           6
# Legendary        False
# Name: 772, dtype: object
# 773 #                 703
# Name          Carbink
# Type 1           Rock
# Type 2          Fairy
# HP                 50
# Attack             50
# Defense           150
# Sp. Atk            50
# Sp. Def           150
# Speed              50
# Generation          6
# Legendary       False
# Name: 773, dtype: object
# 774 #                704
# Name           Goomy
# Type 1        Dragon
# Type 2           NaN
# HP                45
# Attack            50
# Defense           35
# Sp. Atk           55
# Sp. Def           75
# Speed             40
# Generation         6
# Legendary      False
# Name: 774, dtype: object
# 775 #                 705
# Name          Sliggoo
# Type 1         Dragon
# Type 2            NaN
# HP                 68
# Attack             75
# Defense            53
# Sp. Atk            83
# Sp. Def           113
# Speed              60
# Generation          6
# Legendary       False
# Name: 775, dtype: object
# 776 #                706
# Name          Goodra
# Type 1        Dragon
# Type 2           NaN
# HP                90
# Attack           100
# Defense           70
# Sp. Atk          110
# Sp. Def          150
# Speed             80
# Generation         6
# Legendary      False
# Name: 776, dtype: object
# 777 #                707
# Name          Klefki
# Type 1         Steel
# Type 2         Fairy
# HP                57
# Attack            80
# Defense           91
# Sp. Atk           80
# Sp. Def           87
# Speed             75
# Generation         6
# Legendary      False
# Name: 777, dtype: object
# 778 #                  708
# Name          Phantump
# Type 1           Ghost
# Type 2           Grass
# HP                  43
# Attack              70
# Defense             48
# Sp. Atk             50
# Sp. Def             60
# Speed               38
# Generation           6
# Legendary        False
# Name: 778, dtype: object
# 779 #                   709
# Name          Trevenant
# Type 1            Ghost
# Type 2            Grass
# HP                   85
# Attack              110
# Defense              76
# Sp. Atk              65
# Sp. Def              82
# Speed                56
# Generation            6
# Legendary         False
# Name: 779, dtype: object
# 780 #                               710
# Name          PumpkabooAverage Size
# Type 1                        Ghost
# Type 2                        Grass
# HP                               49
# Attack                           66
# Defense                          70
# Sp. Atk                          44
# Sp. Def                          55
# Speed                            51
# Generation                        6
# Legendary                     False
# Name: 780, dtype: object
# 781 #                             710
# Name          PumpkabooSmall Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             44
# Attack                         66
# Defense                        70
# Sp. Atk                        44
# Sp. Def                        55
# Speed                          56
# Generation                      6
# Legendary                   False
# Name: 781, dtype: object
# 782 #                             710
# Name          PumpkabooLarge Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             54
# Attack                         66
# Defense                        70
# Sp. Atk                        44
# Sp. Def                        55
# Speed                          46
# Generation                      6
# Legendary                   False
# Name: 782, dtype: object
# 783 #                             710
# Name          PumpkabooSuper Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             59
# Attack                         66
# Defense                        70
# Sp. Atk                        44
# Sp. Def                        55
# Speed                          41
# Generation                      6
# Legendary                   False
# Name: 783, dtype: object
# 784 #                               711
# Name          GourgeistAverage Size
# Type 1                        Ghost
# Type 2                        Grass
# HP                               65
# Attack                           90
# Defense                         122
# Sp. Atk                          58
# Sp. Def                          75
# Speed                            84
# Generation                        6
# Legendary                     False
# Name: 784, dtype: object
# 785 #                             711
# Name          GourgeistSmall Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             55
# Attack                         85
# Defense                       122
# Sp. Atk                        58
# Sp. Def                        75
# Speed                          99
# Generation                      6
# Legendary                   False
# Name: 785, dtype: object
# 786 #                             711
# Name          GourgeistLarge Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             75
# Attack                         95
# Defense                       122
# Sp. Atk                        58
# Sp. Def                        75
# Speed                          69
# Generation                      6
# Legendary                   False
# Name: 786, dtype: object
# 787 #                             711
# Name          GourgeistSuper Size
# Type 1                      Ghost
# Type 2                      Grass
# HP                             85
# Attack                        100
# Defense                       122
# Sp. Atk                        58
# Sp. Def                        75
# Speed                          54
# Generation                      6
# Legendary                   False
# Name: 787, dtype: object
# 788 #                  712
# Name          Bergmite
# Type 1             Ice
# Type 2             NaN
# HP                  55
# Attack              69
# Defense             85
# Sp. Atk             32
# Sp. Def             35
# Speed               28
# Generation           6
# Legendary        False
# Name: 788, dtype: object
# 789 #                 713
# Name          Avalugg
# Type 1            Ice
# Type 2            NaN
# HP                 95
# Attack            117
# Defense           184
# Sp. Atk            44
# Sp. Def            46
# Speed              28
# Generation          6
# Legendary       False
# Name: 789, dtype: object
# 790 #                714
# Name          Noibat
# Type 1        Flying
# Type 2        Dragon
# HP                40
# Attack            30
# Defense           35
# Sp. Atk           45
# Sp. Def           40
# Speed             55
# Generation         6
# Legendary      False
# Name: 790, dtype: object
# 791 #                 715
# Name          Noivern
# Type 1         Flying
# Type 2         Dragon
# HP                 85
# Attack             70
# Defense            80
# Sp. Atk            97
# Sp. Def            80
# Speed             123
# Generation          6
# Legendary       False
# Name: 791, dtype: object
# 792 #                 716
# Name          Xerneas
# Type 1          Fairy
# Type 2            NaN
# HP                126
# Attack            131
# Defense            95
# Sp. Atk           131
# Sp. Def            98
# Speed              99
# Generation          6
# Legendary        True
# Name: 792, dtype: object
# 793 #                 717
# Name          Yveltal
# Type 1           Dark
# Type 2         Flying
# HP                126
# Attack            131
# Defense            95
# Sp. Atk           131
# Sp. Def            98
# Speed              99
# Generation          6
# Legendary        True
# Name: 793, dtype: object
# 794 #                          718
# Name          Zygarde50% Forme
# Type 1                  Dragon
# Type 2                  Ground
# HP                         108
# Attack                     100
# Defense                    121
# Sp. Atk                     81
# Sp. Def                     95
# Speed                       95
# Generation                   6
# Legendary                 True
# Name: 794, dtype: object
# 795 #                 719
# Name          Diancie
# Type 1           Rock
# Type 2          Fairy
# HP                 50
# Attack            100
# Defense           150
# Sp. Atk           100
# Sp. Def           150
# Speed              50
# Generation          6
# Legendary        True
# Name: 795, dtype: object
# 796 #                             719
# Name          DiancieMega Diancie
# Type 1                       Rock
# Type 2                      Fairy
# HP                             50
# Attack                        160
# Defense                       110
# Sp. Atk                       160
# Sp. Def                       110
# Speed                         110
# Generation                      6
# Legendary                    True
# Name: 796, dtype: object
# 797 #                             720
# Name          HoopaHoopa Confined
# Type 1                    Psychic
# Type 2                      Ghost
# HP                             80
# Attack                        110
# Defense                        60
# Sp. Atk                       150
# Sp. Def                       130
# Speed                          70
# Generation                      6
# Legendary                    True
# Name: 797, dtype: object
# 798 #                            720
# Name          HoopaHoopa Unbound
# Type 1                   Psychic
# Type 2                      Dark
# HP                            80
# Attack                       160
# Defense                       60
# Sp. Atk                      170
# Sp. Def                      130
# Speed                         80
# Generation                     6
# Legendary                   True
# Name: 798, dtype: object
# 799 #                   721
# Name          Volcanion
# Type 1             Fire
# Type 2            Water
# HP                   80
# Attack              110
# Defense             120
# Sp. Atk             130
# Sp. Def              90
# Speed                70
# Generation            6
# Legendary          True
# Name: 799, dtype: object

# %% [markdown]
# Print the values but only the Name column

# %%
for index, row in df.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# 66 Poliwhirl
# 67 Poliwrath
# 68 Abra
# 69 Kadabra
# 70 Alakazam
# 71 AlakazamMega Alakazam
# 72 Machop
# 73 Machoke
# 74 Machamp
# 75 Bellsprout
# 76 Weepinbell
# 77 Victreebel
# 78 Tentacool
# 79 Tentacruel
# 80 Geodude
# 81 Graveler
# 82 Golem
# 83 Ponyta
# 84 Rapidash
# 85 Slowpoke
# 86 Slowbro
# 87 SlowbroMega Slowbro
# 88 Magnemite
# 89 Magneton
# 90 Farfetch'd
# 91 Doduo
# 92 Dodrio
# 93 Seel
# 94 Dewgong
# 95 Grimer
# 96 Muk
# 97 Shellder
# 98 Cloyster
# 99 Gastly
# 100 Haunter
# 101 Gengar
# 102 GengarMega Gengar
# 103 Onix
# 104 Drowzee
# 105 Hypno
# 106 Krabby
# 107 Kingler
# 108 Voltorb
# 109 Electrode
# 110 Exeggcute
# 111 Exeggutor
# 112 Cubone
# 113 Marowak
# 114 Hitmonlee
# 115 Hitmonchan
# 116 Lickitung
# 117 Koffing
# 118 Weezing
# 119 Rhyhorn
# 120 Rhydon
# 121 Chansey
# 122 Tangela
# 123 Kangaskhan
# 124 KangaskhanMega Kangaskhan
# 125 Horsea
# 126 Seadra
# 127 Goldeen
# 128 Seaking
# 129 Staryu
# 130 Starmie
# 131 Mr. Mime
# 132 Scyther
# 133 Jynx
# 134 Electabuzz
# 135 Magmar
# 136 Pinsir
# 137 PinsirMega Pinsir
# 138 Tauros
# 139 Magikarp
# 140 Gyarados
# 141 GyaradosMega Gyarados
# 142 Lapras
# 143 Ditto
# 144 Eevee
# 145 Vaporeon
# 146 Jolteon
# 147 Flareon
# 148 Porygon
# 149 Omanyte
# 150 Omastar
# 151 Kabuto
# 152 Kabutops
# 153 Aerodactyl
# 154 AerodactylMega Aerodactyl
# 155 Snorlax
# 156 Articuno
# 157 Zapdos
# 158 Moltres
# 159 Dratini
# 160 Dragonair
# 161 Dragonite
# 162 Mewtwo
# 163 MewtwoMega Mewtwo X
# 164 MewtwoMega Mewtwo Y
# 165 Mew
# 166 Chikorita
# 167 Bayleef
# 168 Meganium
# 169 Cyndaquil
# 170 Quilava
# 171 Typhlosion
# 172 Totodile
# 173 Croconaw
# 174 Feraligatr
# 175 Sentret
# 176 Furret
# 177 Hoothoot
# 178 Noctowl
# 179 Ledyba
# 180 Ledian
# 181 Spinarak
# 182 Ariados
# 183 Crobat
# 184 Chinchou
# 185 Lanturn
# 186 Pichu
# 187 Cleffa
# 188 Igglybuff
# 189 Togepi
# 190 Togetic
# 191 Natu
# 192 Xatu
# 193 Mareep
# 194 Flaaffy
# 195 Ampharos
# 196 AmpharosMega Ampharos
# 197 Bellossom
# 198 Marill
# 199 Azumarill
# 200 Sudowoodo
# 201 Politoed
# 202 Hoppip
# 203 Skiploom
# 204 Jumpluff
# 205 Aipom
# 206 Sunkern
# 207 Sunflora
# 208 Yanma
# 209 Wooper
# 210 Quagsire
# 211 Espeon
# 212 Umbreon
# 213 Murkrow
# 214 Slowking
# 215 Misdreavus
# 216 Unown
# 217 Wobbuffet
# 218 Girafarig
# 219 Pineco
# 220 Forretress
# 221 Dunsparce
# 222 Gligar
# 223 Steelix
# 224 SteelixMega Steelix
# 225 Snubbull
# 226 Granbull
# 227 Qwilfish
# 228 Scizor
# 229 ScizorMega Scizor
# 230 Shuckle
# 231 Heracross
# 232 HeracrossMega Heracross
# 233 Sneasel
# 234 Teddiursa
# 235 Ursaring
# 236 Slugma
# 237 Magcargo
# 238 Swinub
# 239 Piloswine
# 240 Corsola
# 241 Remoraid
# 242 Octillery
# 243 Delibird
# 244 Mantine
# 245 Skarmory
# 246 Houndour
# 247 Houndoom
# 248 HoundoomMega Houndoom
# 249 Kingdra
# 250 Phanpy
# 251 Donphan
# 252 Porygon2
# 253 Stantler
# 254 Smeargle
# 255 Tyrogue
# 256 Hitmontop
# 257 Smoochum
# 258 Elekid
# 259 Magby
# 260 Miltank
# 261 Blissey
# 262 Raikou
# 263 Entei
# 264 Suicune
# 265 Larvitar
# 266 Pupitar
# 267 Tyranitar
# 268 TyranitarMega Tyranitar
# 269 Lugia
# 270 Ho-oh
# 271 Celebi
# 272 Treecko
# 273 Grovyle
# 274 Sceptile
# 275 SceptileMega Sceptile
# 276 Torchic
# 277 Combusken
# 278 Blaziken
# 279 BlazikenMega Blaziken
# 280 Mudkip
# 281 Marshtomp
# 282 Swampert
# 283 SwampertMega Swampert
# 284 Poochyena
# 285 Mightyena
# 286 Zigzagoon
# 287 Linoone
# 288 Wurmple
# 289 Silcoon
# 290 Beautifly
# 291 Cascoon
# 292 Dustox
# 293 Lotad
# 294 Lombre
# 295 Ludicolo
# 296 Seedot
# 297 Nuzleaf
# 298 Shiftry
# 299 Taillow
# 300 Swellow
# 301 Wingull
# 302 Pelipper
# 303 Ralts
# 304 Kirlia
# 305 Gardevoir
# 306 GardevoirMega Gardevoir
# 307 Surskit
# 308 Masquerain
# 309 Shroomish
# 310 Breloom
# 311 Slakoth
# 312 Vigoroth
# 313 Slaking
# 314 Nincada
# 315 Ninjask
# 316 Shedinja
# 317 Whismur
# 318 Loudred
# 319 Exploud
# 320 Makuhita
# 321 Hariyama
# 322 Azurill
# 323 Nosepass
# 324 Skitty
# 325 Delcatty
# 326 Sableye
# 327 SableyeMega Sableye
# 328 Mawile
# 329 MawileMega Mawile
# 330 Aron
# 331 Lairon
# 332 Aggron
# 333 AggronMega Aggron
# 334 Meditite
# 335 Medicham
# 336 MedichamMega Medicham
# 337 Electrike
# 338 Manectric
# 339 ManectricMega Manectric
# 340 Plusle
# 341 Minun
# 342 Volbeat
# 343 Illumise
# 344 Roselia
# 345 Gulpin
# 346 Swalot
# 347 Carvanha
# 348 Sharpedo
# 349 SharpedoMega Sharpedo
# 350 Wailmer
# 351 Wailord
# 352 Numel
# 353 Camerupt
# 354 CameruptMega Camerupt
# 355 Torkoal
# 356 Spoink
# 357 Grumpig
# 358 Spinda
# 359 Trapinch
# 360 Vibrava
# 361 Flygon
# 362 Cacnea
# 363 Cacturne
# 364 Swablu
# 365 Altaria
# 366 AltariaMega Altaria
# 367 Zangoose
# 368 Seviper
# 369 Lunatone
# 370 Solrock
# 371 Barboach
# 372 Whiscash
# 373 Corphish
# 374 Crawdaunt
# 375 Baltoy
# 376 Claydol
# 377 Lileep
# 378 Cradily
# 379 Anorith
# 380 Armaldo
# 381 Feebas
# 382 Milotic
# 383 Castform
# 384 Kecleon
# 385 Shuppet
# 386 Banette
# 387 BanetteMega Banette
# 388 Duskull
# 389 Dusclops
# 390 Tropius
# 391 Chimecho
# 392 Absol
# 393 AbsolMega Absol
# 394 Wynaut
# 395 Snorunt
# 396 Glalie
# 397 GlalieMega Glalie
# 398 Spheal
# 399 Sealeo
# 400 Walrein
# 401 Clamperl
# 402 Huntail
# 403 Gorebyss
# 404 Relicanth
# 405 Luvdisc
# 406 Bagon
# 407 Shelgon
# 408 Salamence
# 409 SalamenceMega Salamence
# 410 Beldum
# 411 Metang
# 412 Metagross
# 413 MetagrossMega Metagross
# 414 Regirock
# 415 Regice
# 416 Registeel
# 417 Latias
# 418 LatiasMega Latias
# 419 Latios
# 420 LatiosMega Latios
# 421 Kyogre
# 422 KyogrePrimal Kyogre
# 423 Groudon
# 424 GroudonPrimal Groudon
# 425 Rayquaza
# 426 RayquazaMega Rayquaza
# 427 Jirachi
# 428 DeoxysNormal Forme
# 429 DeoxysAttack Forme
# 430 DeoxysDefense Forme
# 431 DeoxysSpeed Forme
# 432 Turtwig
# 433 Grotle
# 434 Torterra
# 435 Chimchar
# 436 Monferno
# 437 Infernape
# 438 Piplup
# 439 Prinplup
# 440 Empoleon
# 441 Starly
# 442 Staravia
# 443 Staraptor
# 444 Bidoof
# 445 Bibarel
# 446 Kricketot
# 447 Kricketune
# 448 Shinx
# 449 Luxio
# 450 Luxray
# 451 Budew
# 452 Roserade
# 453 Cranidos
# 454 Rampardos
# 455 Shieldon
# 456 Bastiodon
# 457 Burmy
# 458 WormadamPlant Cloak
# 459 WormadamSandy Cloak
# 460 WormadamTrash Cloak
# 461 Mothim
# 462 Combee
# 463 Vespiquen
# 464 Pachirisu
# 465 Buizel
# 466 Floatzel
# 467 Cherubi
# 468 Cherrim
# 469 Shellos
# 470 Gastrodon
# 471 Ambipom
# 472 Drifloon
# 473 Drifblim
# 474 Buneary
# 475 Lopunny
# 476 LopunnyMega Lopunny
# 477 Mismagius
# 478 Honchkrow
# 479 Glameow
# 480 Purugly
# 481 Chingling
# 482 Stunky
# 483 Skuntank
# 484 Bronzor
# 485 Bronzong
# 486 Bonsly
# 487 Mime Jr.
# 488 Happiny
# 489 Chatot
# 490 Spiritomb
# 491 Gible
# 492 Gabite
# 493 Garchomp
# 494 GarchompMega Garchomp
# 495 Munchlax
# 496 Riolu
# 497 Lucario
# 498 LucarioMega Lucario
# 499 Hippopotas
# 500 Hippowdon
# 501 Skorupi
# 502 Drapion
# 503 Croagunk
# 504 Toxicroak
# 505 Carnivine
# 506 Finneon
# 507 Lumineon
# 508 Mantyke
# 509 Snover
# 510 Abomasnow
# 511 AbomasnowMega Abomasnow
# 512 Weavile
# 513 Magnezone
# 514 Lickilicky
# 515 Rhyperior
# 516 Tangrowth
# 517 Electivire
# 518 Magmortar
# 519 Togekiss
# 520 Yanmega
# 521 Leafeon
# 522 Glaceon
# 523 Gliscor
# 524 Mamoswine
# 525 Porygon-Z
# 526 Gallade
# 527 GalladeMega Gallade
# 528 Probopass
# 529 Dusknoir
# 530 Froslass
# 531 Rotom
# 532 RotomHeat Rotom
# 533 RotomWash Rotom
# 534 RotomFrost Rotom
# 535 RotomFan Rotom
# 536 RotomMow Rotom
# 537 Uxie
# 538 Mesprit
# 539 Azelf
# 540 Dialga
# 541 Palkia
# 542 Heatran
# 543 Regigigas
# 544 GiratinaAltered Forme
# 545 GiratinaOrigin Forme
# 546 Cresselia
# 547 Phione
# 548 Manaphy
# 549 Darkrai
# 550 ShayminLand Forme
# 551 ShayminSky Forme
# 552 Arceus
# 553 Victini
# 554 Snivy
# 555 Servine
# 556 Serperior
# 557 Tepig
# 558 Pignite
# 559 Emboar
# 560 Oshawott
# 561 Dewott
# 562 Samurott
# 563 Patrat
# 564 Watchog
# 565 Lillipup
# 566 Herdier
# 567 Stoutland
# 568 Purrloin
# 569 Liepard
# 570 Pansage
# 571 Simisage
# 572 Pansear
# 573 Simisear
# 574 Panpour
# 575 Simipour
# 576 Munna
# 577 Musharna
# 578 Pidove
# 579 Tranquill
# 580 Unfezant
# 581 Blitzle
# 582 Zebstrika
# 583 Roggenrola
# 584 Boldore
# 585 Gigalith
# 586 Woobat
# 587 Swoobat
# 588 Drilbur
# 589 Excadrill
# 590 Audino
# 591 AudinoMega Audino
# 592 Timburr
# 593 Gurdurr
# 594 Conkeldurr
# 595 Tympole
# 596 Palpitoad
# 597 Seismitoad
# 598 Throh
# 599 Sawk
# 600 Sewaddle
# 601 Swadloon
# 602 Leavanny
# 603 Venipede
# 604 Whirlipede
# 605 Scolipede
# 606 Cottonee
# 607 Whimsicott
# 608 Petilil
# 609 Lilligant
# 610 Basculin
# 611 Sandile
# 612 Krokorok
# 613 Krookodile
# 614 Darumaka
# 615 DarmanitanStandard Mode
# 616 DarmanitanZen Mode
# 617 Maractus
# 618 Dwebble
# 619 Crustle
# 620 Scraggy
# 621 Scrafty
# 622 Sigilyph
# 623 Yamask
# 624 Cofagrigus
# 625 Tirtouga
# 626 Carracosta
# 627 Archen
# 628 Archeops
# 629 Trubbish
# 630 Garbodor
# 631 Zorua
# 632 Zoroark
# 633 Minccino
# 634 Cinccino
# 635 Gothita
# 636 Gothorita
# 637 Gothitelle
# 638 Solosis
# 639 Duosion
# 640 Reuniclus
# 641 Ducklett
# 642 Swanna
# 643 Vanillite
# 644 Vanillish
# 645 Vanilluxe
# 646 Deerling
# 647 Sawsbuck
# 648 Emolga
# 649 Karrablast
# 650 Escavalier
# 651 Foongus
# 652 Amoonguss
# 653 Frillish
# 654 Jellicent
# 655 Alomomola
# 656 Joltik
# 657 Galvantula
# 658 Ferroseed
# 659 Ferrothorn
# 660 Klink
# 661 Klang
# 662 Klinklang
# 663 Tynamo
# 664 Eelektrik
# 665 Eelektross
# 666 Elgyem
# 667 Beheeyem
# 668 Litwick
# 669 Lampent
# 670 Chandelure
# 671 Axew
# 672 Fraxure
# 673 Haxorus
# 674 Cubchoo
# 675 Beartic
# 676 Cryogonal
# 677 Shelmet
# 678 Accelgor
# 679 Stunfisk
# 680 Mienfoo
# 681 Mienshao
# 682 Druddigon
# 683 Golett
# 684 Golurk
# 685 Pawniard
# 686 Bisharp
# 687 Bouffalant
# 688 Rufflet
# 689 Braviary
# 690 Vullaby
# 691 Mandibuzz
# 692 Heatmor
# 693 Durant
# 694 Deino
# 695 Zweilous
# 696 Hydreigon
# 697 Larvesta
# 698 Volcarona
# 699 Cobalion
# 700 Terrakion
# 701 Virizion
# 702 TornadusIncarnate Forme
# 703 TornadusTherian Forme
# 704 ThundurusIncarnate Forme
# 705 ThundurusTherian Forme
# 706 Reshiram
# 707 Zekrom
# 708 LandorusIncarnate Forme
# 709 LandorusTherian Forme
# 710 Kyurem
# 711 KyuremBlack Kyurem
# 712 KyuremWhite Kyurem
# 713 KeldeoOrdinary Forme
# 714 KeldeoResolute Forme
# 715 MeloettaAria Forme
# 716 MeloettaPirouette Forme
# 717 Genesect
# 718 Chespin
# 719 Quilladin
# 720 Chesnaught
# 721 Fennekin
# 722 Braixen
# 723 Delphox
# 724 Froakie
# 725 Frogadier
# 726 Greninja
# 727 Bunnelby
# 728 Diggersby
# 729 Fletchling
# 730 Fletchinder
# 731 Talonflame
# 732 Scatterbug
# 733 Spewpa
# 734 Vivillon
# 735 Litleo
# 736 Pyroar
# 737 Flabébé
# 738 Floette
# 739 Florges
# 740 Skiddo
# 741 Gogoat
# 742 Pancham
# 743 Pangoro
# 744 Furfrou
# 745 Espurr
# 746 MeowsticMale
# 747 MeowsticFemale
# 748 Honedge
# 749 Doublade
# 750 AegislashBlade Forme
# 751 AegislashShield Forme
# 752 Spritzee
# 753 Aromatisse
# 754 Swirlix
# 755 Slurpuff
# 756 Inkay
# 757 Malamar
# 758 Binacle
# 759 Barbaracle
# 760 Skrelp
# 761 Dragalge
# 762 Clauncher
# 763 Clawitzer
# 764 Helioptile
# 765 Heliolisk
# 766 Tyrunt
# 767 Tyrantrum
# 768 Amaura
# 769 Aurorus
# 770 Sylveon
# 771 Hawlucha
# 772 Dedenne
# 773 Carbink
# 774 Goomy
# 775 Sliggoo
# 776 Goodra
# 777 Klefki
# 778 Phantump
# 779 Trevenant
# 780 PumpkabooAverage Size
# 781 PumpkabooSmall Size
# 782 PumpkabooLarge Size
# 783 PumpkabooSuper Size
# 784 GourgeistAverage Size
# 785 GourgeistSmall Size
# 786 GourgeistLarge Size
# 787 GourgeistSuper Size
# 788 Bergmite
# 789 Avalugg
# 790 Noibat
# 791 Noivern
# 792 Xerneas
# 793 Yveltal
# 794 Zygarde50% Forme
# 795 Diancie
# 796 DiancieMega Diancie
# 797 HoopaHoopa Confined
# 798 HoopaHoopa Unbound
# 799 Volcanion

# %% [markdown]
# Slicing and filter data based on its values

# %%
df.loc[df['Type 1'] == 'Fairy']
# Out:
#        #        Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 40    35    Clefairy  Fairy     NaN   70      45       48       60       65
# 41    36    Clefable  Fairy     NaN   95      70       73       95       90
# 187  173      Cleffa  Fairy     NaN   50      25       28       45       55
# 189  175      Togepi  Fairy     NaN   35      20       65       40       65
# 190  176     Togetic  Fairy  Flying   55      40       85       80      105
# 225  209    Snubbull  Fairy     NaN   60      80       50       40       40
# 226  210    Granbull  Fairy     NaN   90     120       75       60       60
# 519  468    Togekiss  Fairy  Flying   85      50       95      120      115
# 737  669     Flabébé  Fairy     NaN   44      38       39       61       79
# 738  670     Floette  Fairy     NaN   54      45       47       75       98
# 739  671     Florges  Fairy     NaN   78      65       68      112      154
# 752  682    Spritzee  Fairy     NaN   78      52       60       63       65
# 753  683  Aromatisse  Fairy     NaN  101      72       72       99       89
# 754  684     Swirlix  Fairy     NaN   62      48       66       59       57
# 755  685    Slurpuff  Fairy     NaN   82      80       86       85       75
# 770  700     Sylveon  Fairy     NaN   95      65       65      110      130
# 792  716     Xerneas  Fairy     NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# 40      35           1      False
# 41      60           1      False
# 187     15           2      False
# 189     20           2      False
# 190     40           2      False
# 225     30           2      False
# 226     45           2      False
# 519     80           4      False
# 737     42           6      False
# 738     52           6      False
# 739     75           6      False
# 752     23           6      False
# 753     29           6      False
# 754     49           6      False
# 755     72           6      False
# 770     60           6      False
# 792     99           6       True

# %% [markdown]
# Another condition Type

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 48    43                 Oddish  Grass    Poison   45      50       55
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 48        75       65     30           1      False
# ..       ...      ...    ...         ...        ...
# 718       48       45     38           6      False
# 719       56       58     57           6      False
# 720       74       75     64           6      False
# 740       62       57     52           6      False
# 741       97       81     68           6      False
#
# [70 rows x 12 columns]

# %% [markdown]
# The describe() method prints the basic stats of a dataframe

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# max    180.000000     6.00000

# %% [markdown]
# Let's count how many rows has the dataframe

# %%
print(len(df.index)) # Printing the length of the index of the dataframe
print(df.shape) # Printng the shape of the entire dataframe
print(df.shape[0]) # Printing a shape of a single array using the first column
print(df[df.columns[0]].count()) # Printing the count of the first column
# Out:
# 800
# (800, 12)
# 800
# 800

# %% [markdown]
# Sort values by a column and or ascending / descending

# %%
df.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 510       92       85     60           4      False
# 511      132      105     30           4      False
# 68       105       55     90           1      False
# 392       75       60     75           3      False
# 393      115       60    115           3      False
# ..       ...      ...    ...         ...        ...
# 632      120       60    105           5      False
# 631       80       40     65           5      False
# 46        30       40     55           1      False
# 695       65       70     58           5      False
# 794       81       95     95           6       True
#
# [800 rows x 12 columns]

# %%
df.sort_values('Name', ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 794       81       95     95           6       True
# 695       65       70     58           5      False
# 46        30       40     55           1      False
# 631       80       40     65           5      False
# 632      120       60    105           5      False
# ..       ...      ...    ...         ...        ...
# 393      115       60    115           3      False
# 392       75       60     75           3      False
# 68       105       55     90           1      False
# 511      132      105     30           4      False
# 510       92       85     60           4      False
#
# [800 rows x 12 columns]

# %% [markdown]
# Multiple column sort specifying true or false
# (1 & 0) in the ascending value

# %%
df.sort_values(['Type 1', 'Type 2'], ascending=[1,0])
# Out:
#        #                 Name Type 1 Type 2   HP  Attack  Defense  Sp. Atk  \
# 307  283              Surskit    Bug  Water   40      30       32       50
# 220  205           Forretress    Bug  Steel   75      90      140       60
# 228  212               Scizor    Bug  Steel   70     130      100       55
# 229  212    ScizorMega Scizor    Bug  Steel   70     150      140       65
# 460  413  WormadamTrash Cloak    Bug  Steel   60      69       95       69
# ..   ...                  ...    ...    ...  ...     ...      ...      ...
# 655  594            Alomomola  Water    NaN  165      75       80       40
# 724  656              Froakie  Water    NaN   41      56       40       62
# 725  657            Frogadier  Water    NaN   54      63       52       83
# 762  692            Clauncher  Water    NaN   50      53       62       58
# 763  693            Clawitzer  Water    NaN   71      73       88      120
#
#      Sp. Def  Speed  Generation  Legendary
# 307       52     65           3      False
# 220       60     40           2      False
# 228       80     65           2      False
# 229      100     75           2      False
# 460       95     36           4      False
# ..       ...    ...         ...        ...
# 655       45     65           5      False
# 724       44     71           6      False
# 725       56     97           6      False
# 762       63     44           6      False
# 763       89     59           6      False
#
# [800 rows x 12 columns]

# %% [markdown]
# Creating a new column based in the sum of some columns

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# Test the values

# %%
45 + 49 + 49 + 65 + 65 + 45
# Out:
# 318

# %% [markdown]
# Drop a specific or some columns of the dataframe

# %%
df = df.drop(columns= ['Total'])

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Create a column based of the sum() method of some rows  using iloc [all rows, from 5th column to the 9th column], meaning the stats, adding the values horizontally -> ->
#
# Remember zero indexing and inclusive - exclusive limits

# %%
df['Totalv2'] = df.iloc[:,4:10].sum(axis=1)
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Totalv2
# 0       65     45           1      False      318
# 1       80     60           1      False      405
# 2      100     80           1      False      525
# 3      120     80           1      False      625
# 4       50     65           1      False      309

# %% [markdown]
# Move the order of columns of the dataframe

# %%
# Create a list of the column values
cols = list(df.columns.values)

# %%
# df[cols[0:4] + cols[-1] + cols[4:12]]

# %% [markdown]
# Error !, the item cols[-i] is outputted as a string, not a list, so we need to transform it to list in order to concatenate all values into a dataframe

# %%
df[cols[0:4] + [cols[-1]] + cols[4:12]]
# Out:
#        #                   Name   Type 1  Type 2  Totalv2  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      318  45      49
# 1      2                Ivysaur    Grass  Poison      405  60      62
# 2      3               Venusaur    Grass  Poison      525  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      625  80     100
# 4      4             Charmander     Fire     NaN      309  39      52
# ..   ...                    ...      ...     ...      ...  ..     ...
# 795  719                Diancie     Rock   Fairy      600  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy      700  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost      600  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark      680  80     160
# 799  721              Volcanion     Fire   Water      600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         49       65       65     45           1      False
# 1         63       80       80     60           1      False
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 4         43       60       50     65           1      False
# ..       ...      ...      ...    ...         ...        ...
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [800 rows x 13 columns]

# %% [markdown]
# Now we save the dataframe

# %%
df = df[cols[0:4] + [cols[-1]] + cols[4:12]]
df.head()
# Out:
#    #                   Name Type 1  Type 2  Totalv2  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      318  45      49       49
# 1  2                Ivysaur  Grass  Poison      405  60      62       63
# 2  3               Venusaur  Grass  Poison      525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      625  80     100      123
# 4  4             Charmander   Fire     NaN      309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Another way of this doing this

# %%
df = df[['Totalv2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', '#', 'Name', 'Type 1', 'Type 2', 'Generation', 'Legendary']]
df.head()
# Out:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 0      318  45      49       49       65       65     45  1
# 1      405  60      62       63       80       80     60  2
# 2      525  80      82       83      100      100     80  3
# 3      625  80     100      123      122      120     80  3
# 4      309  39      52       43       60       50     65  4
#
#                     Name Type 1  Type 2  Generation  Legendary
# 0              Bulbasaur  Grass  Poison           1      False
# 1                Ivysaur  Grass  Poison           1      False
# 2               Venusaur  Grass  Poison           1      False
# 3  VenusaurMega Venusaur  Grass  Poison           1      False
# 4             Charmander   Fire     NaN           1      False

# %% [markdown]
# Saving the dataframe as a new CSV file, using the to_csv() method and passing the name parameter, note: the new file will be created at the same directory as this jupyter notebook

# %%
df.to_csv('modified_pokemon_df.csv')

# %% [markdown]
# Now lets filter the index so it doesnt get saved with the data

# %%
df.to_csv('modified_pokemon_df.csv', index=False)

# %% [markdown]
# Likewise theres a to_excel() method

# %%
df.to_excel('modified_pokemon_df.xlsx', index=False)

# %% [markdown]
# Now lets save it with more complex parameters, this time using the separator parameter just like the read_csv() method

# %%
df.to_csv('modified_pokemon_df.csv', index=False, sep='\t')

# %%
# Lets save the dataframe again to ease the repeatability of the notebook
df.to_csv('modified_pokemon_df.csv', index=False)

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# Normal filtering: Equal operator ==

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 48       320   45      50       55       75       65     30   43
# ..       ...  ...     ...      ...      ...      ...    ...  ...
# 718      313   56      61       65       48       45     38  650
# 719      405   61      78       95       56       58     57  651
# 720      530   88     107      122       74       75     64  652
# 740      350   66      65       48       62       57     52  672
# 741      531  123     100       62       97       81     68  673
#
#                       Name Type 1    Type 2  Generation  Legendary
# 0                Bulbasaur  Grass    Poison           1      False
# 1                  Ivysaur  Grass    Poison           1      False
# 2                 Venusaur  Grass    Poison           1      False
# 3    VenusaurMega Venusaur  Grass    Poison           1      False
# 48                  Oddish  Grass    Poison           1      False
# ..                     ...    ...       ...         ...        ...
# 718                Chespin  Grass       NaN           6      False
# 719              Quilladin  Grass       NaN           6      False
# 720             Chesnaught  Grass  Fighting           6      False
# 740                 Skiddo  Grass       NaN           6      False
# 741                 Gogoat  Grass       NaN           6      False
#
# [70 rows x 13 columns]

# %% [markdown]
# Normal filtering: Not equal operator !=

# %%
df.loc[df['Type 1'] != 'Grass']
# Out:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 4        309  39      52       43       60       50     65    4
# 5        405  58      64       58       80       65     80    5
# 6        534  78      84       78      109       85    100    6
# 7        634  78     130      111      130       85    100    6
# 8        634  78     104       78      159      115    100    6
# ..       ...  ..     ...      ...      ...      ...    ...  ...
# 795      600  50     100      150      100      150     50  719
# 796      700  50     160      110      160      110    110  719
# 797      600  80     110       60      150      130     70  720
# 798      680  80     160       60      170      130     80  720
# 799      600  80     110      120      130       90     70  721
#
#                           Name   Type 1  Type 2  Generation  Legendary
# 4                   Charmander     Fire     NaN           1      False
# 5                   Charmeleon     Fire     NaN           1      False
# 6                    Charizard     Fire  Flying           1      False
# 7    CharizardMega Charizard X     Fire  Dragon           1      False
# 8    CharizardMega Charizard Y     Fire  Flying           1      False
# ..                         ...      ...     ...         ...        ...
# 795                    Diancie     Rock   Fairy           6       True
# 796        DiancieMega Diancie     Rock   Fairy           6       True
# 797        HoopaHoopa Confined  Psychic   Ghost           6       True
# 798         HoopaHoopa Unbound  Psychic    Dark           6       True
# 799                  Volcanion     Fire   Water           6       True
#
# [730 rows x 13 columns]

# %% [markdown]
# Multiple conditions: And operator &

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 48       320   45      50       55       75       65     30   43
# 49       395   60      65       70       85       75     40   44
# 50       490   75      80       85      110       90     50   45
# 75       300   50      75       35       70       30     40   69
# 76       390   65      90       50       85       45     55   70
# 77       490   80     105       65      100       70     70   71
# 344      400   50      60       45      100       80     65  315
# 451      280   40      30       35       50       70     55  406
# 452      515   60      70       65      125      105     90  407
# 651      294   69      55       45       55       55     15  590
# 652      464  114      85       70       85       80     30  591
#
#                       Name Type 1  Type 2  Generation  Legendary
# 0                Bulbasaur  Grass  Poison           1      False
# 1                  Ivysaur  Grass  Poison           1      False
# 2                 Venusaur  Grass  Poison           1      False
# 3    VenusaurMega Venusaur  Grass  Poison           1      False
# 48                  Oddish  Grass  Poison           1      False
# 49                   Gloom  Grass  Poison           1      False
# 50               Vileplume  Grass  Poison           1      False
# 75              Bellsprout  Grass  Poison           1      False
# 76              Weepinbell  Grass  Poison           1      False
# 77              Victreebel  Grass  Poison           1      False
# 344                Roselia  Grass  Poison           3      False
# 451                  Budew  Grass  Poison           4      False
# 452               Roserade  Grass  Poison           4      False
# 651                Foongus  Grass  Poison           5      False
# 652              Amoonguss  Grass  Poison           5      False

# %% [markdown]
# Multiple conditions: Or operator |

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 1'] == 'Fire')]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 4        309   39      52       43       60       50     65    4
# ..       ...  ...     ...      ...      ...      ...    ...  ...
# 735      369   62      50       58       73       54     72  667
# 736      507   86      68       72      109       66    106  668
# 740      350   66      65       48       62       57     52  672
# 741      531  123     100       62       97       81     68  673
# 799      600   80     110      120      130       90     70  721
#
#                       Name Type 1  Type 2  Generation  Legendary
# 0                Bulbasaur  Grass  Poison           1      False
# 1                  Ivysaur  Grass  Poison           1      False
# 2                 Venusaur  Grass  Poison           1      False
# 3    VenusaurMega Venusaur  Grass  Poison           1      False
# 4               Charmander   Fire     NaN           1      False
# ..                     ...    ...     ...         ...        ...
# 735                 Litleo   Fire  Normal           6      False
# 736                 Pyroar   Fire  Normal           6      False
# 740                 Skiddo  Grass     NaN           6      False
# 741                 Gogoat  Grass     NaN           6      False
# 799              Volcanion   Fire   Water           6       True
#
# [122 rows x 13 columns]

# %% [markdown]
# Combination of filters

# %%
df.loc[(df['Attack'] > 80) & (df['Type 1'] == 'Grass') | (df['Type 1'] == 'Poison')]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 28       288   35      60       44       40       54     55   23
# 29       438   60      85       69       65       79     80   24
# 34       275   55      47       52       40       40     41   29
# 35       365   70      62       67       55       55     56   30
# 36       505   90      92       87       75       85     76   31
# 37       273   46      57       40       40       40     50   32
# 38       365   61      72       57       55       55     65   33
# 39       505   81     102       77       85       75     85   34
# 46       245   40      45       35       30       40     55   41
# 47       455   75      80       70       65       75     90   42
# 76       390   65      90       50       85       45     55   70
# 77       490   80     105       65      100       70     70   71
# 95       325   80      80       50       40       50     25   88
# 96       500  105     105       75       65      100     50   89
# 111      520   95      95       85      125       65     55  103
# 117      340   40      65       95       60       45     35  109
# 118      490   65      90      120       85       70     60  110
# 168      525   80      82      100       83      100     80  154
# 183      535   85      90       80       70       80    130  169
# 274      530   70      85       65      105       85    120  254
# 275      630   70     110       75      145       85    145  254
# 298      480   90     100       60       90       60     80  275
# 310      460   60     130       80       60       60     70  286
# 345      302   70      43       53       43       53     40  316
# 346      467  100      73       83       73       83     55  317
# 362      335   50      85       40       85       40     35  331
# 363      475   70     115       60      115       60     55  332
# 368      458   73     100       60      100       60     65  336
# 433      405   75      89       85       55       65     36  388
# 434      525   95     109      105       75       85     56  389
# 482      329   63      63       47       41       41     74  434
# 483      479  103      93       67       71       61     84  435
# 501      330   40      50       90       30       55     65  451
# 502      500   70      90      110       60       75     95  452
# 503      300   48      61       40       61       40     50  453
# 504      490   83     106       65       86       65     85  454
# 505      454   74     100       72       90       72     46  455
# 510      494   90      92       75       92       85     60  460
# 511      594   90     132      105      132      105     30  460
# 516      535  100     100      125      110       50     50  465
# 521      525   65     110      130       60       65     95  470
# 550      600  100     100      100      100      100    100  492
# 551      600  100     103       75      120       75    127  492
# 571      498   75      98       63       98       63    101  512
# 617      461   75      86       67      106       67     60  556
# 629      329   50      50       62       40       62     65  568
# 630      474   80      95       82       60       82     75  569
# 652      464  114      85       70       85       80     30  591
# 659      489   74      94      131       54      116     20  598
# 701      580   91      90       72       90      129    108  640
# 720      530   88     107      122       74       75     64  652
# 741      531  123     100       62       97       81     68  673
# 760      320   50      60       60       60       60     30  690
# 761      494   65      75       90       97      123     44  691
#
#                         Name  Type 1    Type 2  Generation  Legendary
# 2                   Venusaur   Grass    Poison           1      False
# 3      VenusaurMega Venusaur   Grass    Poison           1      False
# 28                     Ekans  Poison       NaN           1      False
# 29                     Arbok  Poison       NaN           1      False
# 34          Nidoran (Female)  Poison       NaN           1      False
# 35                  Nidorina  Poison       NaN           1      False
# 36                 Nidoqueen  Poison    Ground           1      False
# 37            Nidoran (Male)  Poison       NaN           1      False
# 38                  Nidorino  Poison       NaN           1      False
# 39                  Nidoking  Poison    Ground           1      False
# 46                     Zubat  Poison    Flying           1      False
# 47                    Golbat  Poison    Flying           1      False
# 76                Weepinbell   Grass    Poison           1      False
# 77                Victreebel   Grass    Poison           1      False
# 95                    Grimer  Poison       NaN           1      False
# 96                       Muk  Poison       NaN           1      False
# 111                Exeggutor   Grass   Psychic           1      False
# 117                  Koffing  Poison       NaN           1      False
# 118                  Weezing  Poison       NaN           1      False
# 168                 Meganium   Grass       NaN           2      False
# 183                   Crobat  Poison    Flying           2      False
# 274                 Sceptile   Grass       NaN           3      False
# 275    SceptileMega Sceptile   Grass    Dragon           3      False
# 298                  Shiftry   Grass      Dark           3      False
# 310                  Breloom   Grass  Fighting           3      False
# 345                   Gulpin  Poison       NaN           3      False
# 346                   Swalot  Poison       NaN           3      False
# 362                   Cacnea   Grass       NaN           3      False
# 363                 Cacturne   Grass      Dark           3      False
# 368                  Seviper  Poison       NaN           3      False
# 433                   Grotle   Grass       NaN           4      False
# 434                 Torterra   Grass    Ground           4      False
# 482                   Stunky  Poison      Dark           4      False
# 483                 Skuntank  Poison      Dark           4      False
# 501                  Skorupi  Poison       Bug           4      False
# 502                  Drapion  Poison      Dark           4      False
# 503                 Croagunk  Poison  Fighting           4      False
# 504                Toxicroak  Poison  Fighting           4      False
# 505                Carnivine   Grass       NaN           4      False
# 510                Abomasnow   Grass       Ice           4      False
# 511  AbomasnowMega Abomasnow   Grass       Ice           4      False
# 516                Tangrowth   Grass       NaN           4      False
# 521                  Leafeon   Grass       NaN           4      False
# 550        ShayminLand Forme   Grass       NaN           4       True
# 551         ShayminSky Forme   Grass    Flying           4       True
# 571                 Simisage   Grass       NaN           5      False
# 617                 Maractus   Grass       NaN           5      False
# 629                 Trubbish  Poison       NaN           5      False
# 630                 Garbodor  Poison       NaN           5      False
# 652                Amoonguss   Grass    Poison           5      False
# 659               Ferrothorn   Grass     Steel           5      False
# 701                 Virizion   Grass  Fighting           5       True
# 720               Chesnaught   Grass  Fighting           6      False
# 741                   Gogoat   Grass       NaN           6      False
# 760                   Skrelp  Poison     Water           6      False
# 761                 Dragalge  Poison    Dragon           6      False

# %% [markdown]
# now lets save it to a new df

# %%
df_filter = df.loc[(df['Attack'] > 80) & (df['Type 1'] == 'Grass') | (df['Type 1'] == 'Poison')]
df_filter.head(30)
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 28       288   35      60       44       40       54     55   23
# 29       438   60      85       69       65       79     80   24
# 34       275   55      47       52       40       40     41   29
# 35       365   70      62       67       55       55     56   30
# 36       505   90      92       87       75       85     76   31
# 37       273   46      57       40       40       40     50   32
# 38       365   61      72       57       55       55     65   33
# 39       505   81     102       77       85       75     85   34
# 46       245   40      45       35       30       40     55   41
# 47       455   75      80       70       65       75     90   42
# 76       390   65      90       50       85       45     55   70
# 77       490   80     105       65      100       70     70   71
# 95       325   80      80       50       40       50     25   88
# 96       500  105     105       75       65      100     50   89
# 111      520   95      95       85      125       65     55  103
# 117      340   40      65       95       60       45     35  109
# 118      490   65      90      120       85       70     60  110
# 168      525   80      82      100       83      100     80  154
# 183      535   85      90       80       70       80    130  169
# 274      530   70      85       65      105       85    120  254
# 275      630   70     110       75      145       85    145  254
# 298      480   90     100       60       90       60     80  275
# 310      460   60     130       80       60       60     70  286
# 345      302   70      43       53       43       53     40  316
# 346      467  100      73       83       73       83     55  317
# 362      335   50      85       40       85       40     35  331
# 363      475   70     115       60      115       60     55  332
# 368      458   73     100       60      100       60     65  336
#
#                       Name  Type 1    Type 2  Generation  Legendary
# 2                 Venusaur   Grass    Poison           1      False
# 3    VenusaurMega Venusaur   Grass    Poison           1      False
# 28                   Ekans  Poison       NaN           1      False
# 29                   Arbok  Poison       NaN           1      False
# 34        Nidoran (Female)  Poison       NaN           1      False
# 35                Nidorina  Poison       NaN           1      False
# 36               Nidoqueen  Poison    Ground           1      False
# 37          Nidoran (Male)  Poison       NaN           1      False
# 38                Nidorino  Poison       NaN           1      False
# 39                Nidoking  Poison    Ground           1      False
# 46                   Zubat  Poison    Flying           1      False
# 47                  Golbat  Poison    Flying           1      False
# 76              Weepinbell   Grass    Poison           1      False
# 77              Victreebel   Grass    Poison           1      False
# 95                  Grimer  Poison       NaN           1      False
# 96                     Muk  Poison       NaN           1      False
# 111              Exeggutor   Grass   Psychic           1      False
# 117                Koffing  Poison       NaN           1      False
# 118                Weezing  Poison       NaN           1      False
# 168               Meganium   Grass       NaN           2      False
# 183                 Crobat  Poison    Flying           2      False
# 274               Sceptile   Grass       NaN           3      False
# 275  SceptileMega Sceptile   Grass    Dragon           3      False
# 298                Shiftry   Grass      Dark           3      False
# 310                Breloom   Grass  Fighting           3      False
# 345                 Gulpin  Poison       NaN           3      False
# 346                 Swalot  Poison       NaN           3      False
# 362                 Cacnea   Grass       NaN           3      False
# 363               Cacturne   Grass      Dark           3      False
# 368                Seviper  Poison       NaN           3      False

# %% [markdown]
# We can see the new dataframe keeps the same index structure, this can be cumbersome in further slicing, so lets reset the index of the dataframe

# %%
df_filter = df_filter.reset_index()
df_filter.head(15)
# Out:
#     index  Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 0       2      525  80      82       83      100      100     80   3
# 1       3      625  80     100      123      122      120     80   3
# 2      28      288  35      60       44       40       54     55  23
# 3      29      438  60      85       69       65       79     80  24
# 4      34      275  55      47       52       40       40     41  29
# 5      35      365  70      62       67       55       55     56  30
# 6      36      505  90      92       87       75       85     76  31
# 7      37      273  46      57       40       40       40     50  32
# 8      38      365  61      72       57       55       55     65  33
# 9      39      505  81     102       77       85       75     85  34
# 10     46      245  40      45       35       30       40     55  41
# 11     47      455  75      80       70       65       75     90  42
# 12     76      390  65      90       50       85       45     55  70
# 13     77      490  80     105       65      100       70     70  71
# 14     95      325  80      80       50       40       50     25  88
#
#                      Name  Type 1  Type 2  Generation  Legendary
# 0                Venusaur   Grass  Poison           1      False
# 1   VenusaurMega Venusaur   Grass  Poison           1      False
# 2                   Ekans  Poison     NaN           1      False
# 3                   Arbok  Poison     NaN           1      False
# 4        Nidoran (Female)  Poison     NaN           1      False
# 5                Nidorina  Poison     NaN           1      False
# 6               Nidoqueen  Poison  Ground           1      False
# 7          Nidoran (Male)  Poison     NaN           1      False
# 8                Nidorino  Poison     NaN           1      False
# 9                Nidoking  Poison  Ground           1      False
# 10                  Zubat  Poison  Flying           1      False
# 11                 Golbat  Poison  Flying           1      False
# 12             Weepinbell   Grass  Poison           1      False
# 13             Victreebel   Grass  Poison           1      False
# 14                 Grimer  Poison     NaN           1      False

# %% [markdown]
# We can see it created two new columns, the old index named as Index and the new index named level_0, we can drop these column too

# %%
df_filter = df_filter.reset_index(drop=True)
df_filter.head(15)
# Out:
#     index  Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 0       2      525  80      82       83      100      100     80   3
# 1       3      625  80     100      123      122      120     80   3
# 2      28      288  35      60       44       40       54     55  23
# 3      29      438  60      85       69       65       79     80  24
# 4      34      275  55      47       52       40       40     41  29
# 5      35      365  70      62       67       55       55     56  30
# 6      36      505  90      92       87       75       85     76  31
# 7      37      273  46      57       40       40       40     50  32
# 8      38      365  61      72       57       55       55     65  33
# 9      39      505  81     102       77       85       75     85  34
# 10     46      245  40      45       35       30       40     55  41
# 11     47      455  75      80       70       65       75     90  42
# 12     76      390  65      90       50       85       45     55  70
# 13     77      490  80     105       65      100       70     70  71
# 14     95      325  80      80       50       40       50     25  88
#
#                      Name  Type 1  Type 2  Generation  Legendary
# 0                Venusaur   Grass  Poison           1      False
# 1   VenusaurMega Venusaur   Grass  Poison           1      False
# 2                   Ekans  Poison     NaN           1      False
# 3                   Arbok  Poison     NaN           1      False
# 4        Nidoran (Female)  Poison     NaN           1      False
# 5                Nidorina  Poison     NaN           1      False
# 6               Nidoqueen  Poison  Ground           1      False
# 7          Nidoran (Male)  Poison     NaN           1      False
# 8                Nidorino  Poison     NaN           1      False
# 9                Nidoking  Poison  Ground           1      False
# 10                  Zubat  Poison  Flying           1      False
# 11                 Golbat  Poison  Flying           1      False
# 12             Weepinbell   Grass  Poison           1      False
# 13             Victreebel   Grass  Poison           1      False
# 14                 Grimer  Poison     NaN           1      False

# %% [markdown]
# We can also reset it without assign its values to a new/another column

# %%
df_filter.reset_index(drop=True, inplace=True)
df_filter.head(15)
# Out:
#     index  Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 0       2      525  80      82       83      100      100     80   3
# 1       3      625  80     100      123      122      120     80   3
# 2      28      288  35      60       44       40       54     55  23
# 3      29      438  60      85       69       65       79     80  24
# 4      34      275  55      47       52       40       40     41  29
# 5      35      365  70      62       67       55       55     56  30
# 6      36      505  90      92       87       75       85     76  31
# 7      37      273  46      57       40       40       40     50  32
# 8      38      365  61      72       57       55       55     65  33
# 9      39      505  81     102       77       85       75     85  34
# 10     46      245  40      45       35       30       40     55  41
# 11     47      455  75      80       70       65       75     90  42
# 12     76      390  65      90       50       85       45     55  70
# 13     77      490  80     105       65      100       70     70  71
# 14     95      325  80      80       50       40       50     25  88
#
#                      Name  Type 1  Type 2  Generation  Legendary
# 0                Venusaur   Grass  Poison           1      False
# 1   VenusaurMega Venusaur   Grass  Poison           1      False
# 2                   Ekans  Poison     NaN           1      False
# 3                   Arbok  Poison     NaN           1      False
# 4        Nidoran (Female)  Poison     NaN           1      False
# 5                Nidorina  Poison     NaN           1      False
# 6               Nidoqueen  Poison  Ground           1      False
# 7          Nidoran (Male)  Poison     NaN           1      False
# 8                Nidorino  Poison     NaN           1      False
# 9                Nidoking  Poison  Ground           1      False
# 10                  Zubat  Poison  Flying           1      False
# 11                 Golbat  Poison  Flying           1      False
# 12             Weepinbell   Grass  Poison           1      False
# 13             Victreebel   Grass  Poison           1      False
# 14                 Grimer  Poison     NaN           1      False

# %% [markdown]
# Or we can just simply drop the column

# %%
df_filter = df_filter.drop(columns=['index'])
df_filter.head(15)
# Out:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 0       525  80      82       83      100      100     80   3
# 1       625  80     100      123      122      120     80   3
# 2       288  35      60       44       40       54     55  23
# 3       438  60      85       69       65       79     80  24
# 4       275  55      47       52       40       40     41  29
# 5       365  70      62       67       55       55     56  30
# 6       505  90      92       87       75       85     76  31
# 7       273  46      57       40       40       40     50  32
# 8       365  61      72       57       55       55     65  33
# 9       505  81     102       77       85       75     85  34
# 10      245  40      45       35       30       40     55  41
# 11      455  75      80       70       65       75     90  42
# 12      390  65      90       50       85       45     55  70
# 13      490  80     105       65      100       70     70  71
# 14      325  80      80       50       40       50     25  88
#
#                      Name  Type 1  Type 2  Generation  Legendary
# 0                Venusaur   Grass  Poison           1      False
# 1   VenusaurMega Venusaur   Grass  Poison           1      False
# 2                   Ekans  Poison     NaN           1      False
# 3                   Arbok  Poison     NaN           1      False
# 4        Nidoran (Female)  Poison     NaN           1      False
# 5                Nidorina  Poison     NaN           1      False
# 6               Nidoqueen  Poison  Ground           1      False
# 7          Nidoran (Male)  Poison     NaN           1      False
# 8                Nidorino  Poison     NaN           1      False
# 9                Nidoking  Poison  Ground           1      False
# 10                  Zubat  Poison  Flying           1      False
# 11                 Golbat  Poison  Flying           1      False
# 12             Weepinbell   Grass  Poison           1      False
# 13             Victreebel   Grass  Poison           1      False
# 14                 Grimer  Poison     NaN           1      False

# %% [markdown]
# Advanced filtering: find all the rows with the string Mega in the name column, all Mega Evolved pokemon are in the output (sidenote: Meganium too xd)

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 3        625   80     100      123      122      120     80    3
# 7        634   78     130      111      130       85    100    6
# 8        634   78     104       78      159      115    100    6
# 12       630   79     103      120      135      115     78    9
# 19       495   65     150       40       15       80    145   15
# 23       579   83      80       80      135       80    121   18
# 71       590   55      50       65      175       95    150   65
# 87       590   95      75      180      130       80     30   80
# 102      600   60      65       80      170       95    130   94
# 124      590  105     125      100       60      100    100  115
# 137      600   65     155      120       65       90    105  127
# 141      640   95     155      109       70      130     81  130
# 154      615   80     135       85       70       95    150  142
# 163      780  106     190      100      154      100    130  150
# 164      780  106     150       70      194      120    140  150
# 168      525   80      82      100       83      100     80  154
# 196      610   90      95      105      165      110     45  181
# 224      610   75     125      230       55       95     30  208
# 229      600   70     150      140       65      100     75  212
# 232      600   80     185      115       40      105     75  214
# 248      600   75      90       90      140       90    115  229
# 268      700  100     164      150       95      120     71  248
# 275      630   70     110       75      145       85    145  254
# 279      630   80     160       80      130       80    100  257
# 283      635  100     150      110       95      110     70  260
# 306      618   68      85       65      165      135    100  282
# 327      480   50      85      125       85      115     20  302
# 329      480   50     105      125       55       95     50  303
# 333      630   70     140      230       60       80     50  306
# 336      510   60     100       85       80       85    100  308
# 339      575   70      75       80      135       80    135  310
# 349      560   70     140       70      110       65    105  319
# 354      560   70     120      100      145      105     20  323
# 366      590   75     110      110      110      105     80  334
# 387      555   64     165       75       93       83     75  354
# 393      565   65     150       60      115       60    115  359
# 397      580   80     120       80      120       80    100  362
# 409      700   95     145      130      120       90    120  373
# 413      700   80     145      150      105      110    110  376
# 418      700   80     100      120      140      150    110  380
# 420      700   80     130      100      160      120    110  381
# 426      780  105     180      100      180      100    115  384
# 476      580   65     136       94       54       96    135  428
# 494      700  108     170      115      120       95     92  445
# 498      625   70     145       88      140       70    112  448
# 511      594   90     132      105      132      105     30  460
# 527      618   68     165       95       65      115    110  475
# 591      545  103      60      126       80      126     50  531
# 796      700   50     160      110      160      110    110  719
#
#                           Name    Type 1    Type 2  Generation  Legendary
# 3        VenusaurMega Venusaur     Grass    Poison           1      False
# 7    CharizardMega Charizard X      Fire    Dragon           1      False
# 8    CharizardMega Charizard Y      Fire    Flying           1      False
# 12     BlastoiseMega Blastoise     Water       NaN           1      False
# 19       BeedrillMega Beedrill       Bug    Poison           1      False
# 23         PidgeotMega Pidgeot    Normal    Flying           1      False
# 71       AlakazamMega Alakazam   Psychic       NaN           1      False
# 87         SlowbroMega Slowbro     Water   Psychic           1      False
# 102          GengarMega Gengar     Ghost    Poison           1      False
# 124  KangaskhanMega Kangaskhan    Normal       NaN           1      False
# 137          PinsirMega Pinsir       Bug    Flying           1      False
# 141      GyaradosMega Gyarados     Water      Dark           1      False
# 154  AerodactylMega Aerodactyl      Rock    Flying           1      False
# 163        MewtwoMega Mewtwo X   Psychic  Fighting           1       True
# 164        MewtwoMega Mewtwo Y   Psychic       NaN           1       True
# 168                   Meganium     Grass       NaN           2      False
# 196      AmpharosMega Ampharos  Electric    Dragon           2      False
# 224        SteelixMega Steelix     Steel    Ground           2      False
# 229          ScizorMega Scizor       Bug     Steel           2      False
# 232    HeracrossMega Heracross       Bug  Fighting           2      False
# 248      HoundoomMega Houndoom      Dark      Fire           2      False
# 268    TyranitarMega Tyranitar      Rock      Dark           2      False
# 275      SceptileMega Sceptile     Grass    Dragon           3      False
# 279      BlazikenMega Blaziken      Fire  Fighting           3      False
# 283      SwampertMega Swampert     Water    Ground           3      False
# 306    GardevoirMega Gardevoir   Psychic     Fairy           3      False
# 327        SableyeMega Sableye      Dark     Ghost           3      False
# 329          MawileMega Mawile     Steel     Fairy           3      False
# 333          AggronMega Aggron     Steel       NaN           3      False
# 336      MedichamMega Medicham  Fighting   Psychic           3      False
# 339    ManectricMega Manectric  Electric       NaN           3      False
# 349      SharpedoMega Sharpedo     Water      Dark           3      False
# 354      CameruptMega Camerupt      Fire    Ground           3      False
# 366        AltariaMega Altaria    Dragon     Fairy           3      False
# 387        BanetteMega Banette     Ghost       NaN           3      False
# 393            AbsolMega Absol      Dark       NaN           3      False
# 397          GlalieMega Glalie       Ice       NaN           3      False
# 409    SalamenceMega Salamence    Dragon    Flying           3      False
# 413    MetagrossMega Metagross     Steel   Psychic           3      False
# 418          LatiasMega Latias    Dragon   Psychic           3       True
# 420          LatiosMega Latios    Dragon   Psychic           3       True
# 426      RayquazaMega Rayquaza    Dragon    Flying           3       True
# 476        LopunnyMega Lopunny    Normal  Fighting           4      False
# 494      GarchompMega Garchomp    Dragon    Ground           4      False
# 498        LucarioMega Lucario  Fighting     Steel           4      False
# 511    AbomasnowMega Abomasnow     Grass       Ice           4      False
# 527        GalladeMega Gallade   Psychic  Fighting           4      False
# 591          AudinoMega Audino    Normal     Fairy           5      False
# 796        DiancieMega Diancie      Rock     Fairy           6       True

# %% [markdown]
# Now lets do the opposite, using the loc method() we can specify NOT  IN with ~, its a weird way of doing it having not equal as !=, but that's the way

# %%
df.loc[~df['Name'].str.contains('Mega')]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 4        309   39      52       43       60       50     65    4
# 5        405   58      64       58       80       65     80    5
# ..       ...  ...     ...      ...      ...      ...    ...  ...
# 794      600  108     100      121       81       95     95  718
# 795      600   50     100      150      100      150     50  719
# 797      600   80     110       60      150      130     70  720
# 798      680   80     160       60      170      130     80  720
# 799      600   80     110      120      130       90     70  721
#
#                     Name   Type 1  Type 2  Generation  Legendary
# 0              Bulbasaur    Grass  Poison           1      False
# 1                Ivysaur    Grass  Poison           1      False
# 2               Venusaur    Grass  Poison           1      False
# 4             Charmander     Fire     NaN           1      False
# 5             Charmeleon     Fire     NaN           1      False
# ..                   ...      ...     ...         ...        ...
# 794     Zygarde50% Forme   Dragon  Ground           6       True
# 795              Diancie     Rock   Fairy           6       True
# 797  HoopaHoopa Confined  Psychic   Ghost           6       True
# 798   HoopaHoopa Unbound  Psychic    Dark           6       True
# 799            Volcanion     Fire   Water           6       True
#
# [751 rows x 13 columns]

# %% [markdown]
# The contains method is super powerful, it can be used with python regular expressions and advanced filtering, lets import the library and test it

# %%
import re
df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 4        309   39      52       43       60       50     65    4
# ..       ...  ...     ...      ...      ...      ...    ...  ...
# 735      369   62      50       58       73       54     72  667
# 736      507   86      68       72      109       66    106  668
# 740      350   66      65       48       62       57     52  672
# 741      531  123     100       62       97       81     68  673
# 799      600   80     110      120      130       90     70  721
#
#                       Name Type 1  Type 2  Generation  Legendary
# 0                Bulbasaur  Grass  Poison           1      False
# 1                  Ivysaur  Grass  Poison           1      False
# 2                 Venusaur  Grass  Poison           1      False
# 3    VenusaurMega Venusaur  Grass  Poison           1      False
# 4               Charmander   Fire     NaN           1      False
# ..                     ...    ...     ...         ...        ...
# 735                 Litleo   Fire  Normal           6      False
# 736                 Pyroar   Fire  Normal           6      False
# 740                 Skiddo  Grass     NaN           6      False
# 741                 Gogoat  Grass     NaN           6      False
# 799              Volcanion   Fire   Water           6       True
#
# [122 rows x 13 columns]

# %% [markdown]
# Now let's utilize more parameters like the flags=re.I that ignores capitalization in the filtering

# %%
import re
df.loc[df['Type 1'].str.contains('fire|grass', regex=True, flags=re.IGNORECASE)]
# Another way 
# df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True, flags=re.IGNORECASE)]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 0        318   45      49       49       65       65     45    1
# 1        405   60      62       63       80       80     60    2
# 2        525   80      82       83      100      100     80    3
# 3        625   80     100      123      122      120     80    3
# 4        309   39      52       43       60       50     65    4
# ..       ...  ...     ...      ...      ...      ...    ...  ...
# 735      369   62      50       58       73       54     72  667
# 736      507   86      68       72      109       66    106  668
# 740      350   66      65       48       62       57     52  672
# 741      531  123     100       62       97       81     68  673
# 799      600   80     110      120      130       90     70  721
#
#                       Name Type 1  Type 2  Generation  Legendary
# 0                Bulbasaur  Grass  Poison           1      False
# 1                  Ivysaur  Grass  Poison           1      False
# 2                 Venusaur  Grass  Poison           1      False
# 3    VenusaurMega Venusaur  Grass  Poison           1      False
# 4               Charmander   Fire     NaN           1      False
# ..                     ...    ...     ...         ...        ...
# 735                 Litleo   Fire  Normal           6      False
# 736                 Pyroar   Fire  Normal           6      False
# 740                 Skiddo  Grass     NaN           6      False
# 741                 Gogoat  Grass     NaN           6      False
# 799              Volcanion   Fire   Water           6       True
#
# [122 rows x 13 columns]

# %% [markdown]
# All pokemon names that start with with 'Pi'

# %%
# re.I is the same as re.IGNORECASE
# [a-z] all leters
# * zero or more occurences of the pattern
# + one or more occurences of the pattern
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 20       251   40      45       40       35       35     56   16
# 21       349   63      60       55       50       50     71   17
# 22       479   83      80       75       70       70    101   18
# 23       579   83      80       80      135       80    121   18
# 30       320   35      55       40       50       50     90   25
# 136      500   65     125      100       55       70     85  127
# 137      600   65     155      120       65       90    105  127
# 186      205   20      40       15       35       35     60  172
# 219      290   50      65       90       35       35     15  204
# 239      450  100     100       80       60       60     50  221
# 438      314   53      51       53       61       56     40  393
# 558      418   90      93       55       70       55     55  499
# 578      264   50      55       50       36       30     43  519
#
#                     Name    Type 1    Type 2  Generation  Legendary
# 20                Pidgey    Normal    Flying           1      False
# 21             Pidgeotto    Normal    Flying           1      False
# 22               Pidgeot    Normal    Flying           1      False
# 23   PidgeotMega Pidgeot    Normal    Flying           1      False
# 30               Pikachu  Electric       NaN           1      False
# 136               Pinsir       Bug       NaN           1      False
# 137    PinsirMega Pinsir       Bug    Flying           1      False
# 186                Pichu  Electric       NaN           2      False
# 219               Pineco       Bug       NaN           2      False
# 239            Piloswine       Ice    Ground           2      False
# 438               Piplup     Water       NaN           4      False
# 558              Pignite      Fire  Fighting           5      False
# 578               Pidove    Normal    Flying           5      False

# %% [markdown]
# ## Conditional changes

# %%
df.head()
# Out:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 0      318  45      49       49       65       65     45  1
# 1      405  60      62       63       80       80     60  2
# 2      525  80      82       83      100      100     80  3
# 3      625  80     100      123      122      120     80  3
# 4      309  39      52       43       60       50     65  4
#
#                     Name Type 1  Type 2  Generation  Legendary
# 0              Bulbasaur  Grass  Poison           1      False
# 1                Ivysaur  Grass  Poison           1      False
# 2               Venusaur  Grass  Poison           1      False
# 3  VenusaurMega Venusaur  Grass  Poison           1      False
# 4             Charmander   Fire     NaN           1      False

# %% [markdown]
# Editing a column based on a condition

# %%
df['Type 1'].loc[df['Type 1'] == 'Fire'] = 'Flame'

# %%
# Another Way to do it 
df.loc[df['Type 1'] == 'Flame', 'Type 1'] = 'Flamer'

# %%
df.loc[df['Name'] == 'Charizard']
# Out:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #       Name  \
# 6      534  78      84       78      109       85    100  6  Charizard
#
#    Type 1  Type 2  Generation  Legendary
# 6  Flamer  Flying           1      False

# %%
# Revert back to normal 
df.loc[df['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
df.loc[df['Type 1'] == 'Fire']
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 4        309   39      52       43       60       50     65    4
# 5        405   58      64       58       80       65     80    5
# 6        534   78      84       78      109       85    100    6
# 7        634   78     130      111      130       85    100    6
# 8        634   78     104       78      159      115    100    6
# 42       299   38      41       40       50       65     65   37
# 43       505   73      76       75       81      100    100   38
# 63       350   55      70       45       70       50     60   58
# 64       555   90     110       80      100       80     95   59
# 83       410   50      85       55       65       65     90   77
# 84       500   65     100       70       80       80    105   78
# 135      495   65      95       57      100       85     93  126
# 147      525   65     130       60       95      110     65  136
# 158      580   90     100       90      125       85     90  146
# 169      309   39      52       43       60       50     65  155
# 170      405   58      64       58       80       65     80  156
# 171      534   78      84       78      109       85    100  157
# 236      250   40      40       40       70       40     20  218
# 237      410   50      50      120       80       80     30  219
# 259      365   45      75       37       70       55     83  240
# 263      580  115     115       85       90       75    100  244
# 270      680  106     130       90      110      154     90  250
# 276      310   45      60       40       70       50     45  255
# 277      405   60      85       60       85       60     55  256
# 278      530   80     120       70      110       70     80  257
# 279      630   80     160       80      130       80    100  257
# 352      305   60      60       40       65       45     35  322
# 353      460   70     100       70      105       75     40  323
# 354      560   70     120      100      145      105     20  323
# 355      470   70      85      140       85       70     20  324
# 435      309   44      58       44       58       44     61  390
# 436      405   64      78       52       78       52     81  391
# 437      534   76     104       71      104       71    108  392
# 518      540   75      95       67      125       95     83  467
# 542      600   91      90      106      130      106     77  485
# 557      308   65      63       45       45       45     45  498
# 558      418   90      93       55       70       55     55  499
# 559      528  110     123       65      100       65     65  500
# 572      316   50      53       48       53       48     64  513
# 573      498   75      98       63       98       63    101  514
# 614      315   70      90       45       15       45     50  554
# 615      480  105     140       55       30       55     95  555
# 616      540  105      30      105      140      105     55  555
# 692      484   85      97       66      105       66     65  631
# 721      307   40      45       40       62       60     60  653
# 722      409   59      59       58       90       70     73  654
# 723      534   75      69       72      114      100    104  655
# 730      382   62      73       55       56       52     84  662
# 731      499   78      81       71       74       69    126  663
# 735      369   62      50       58       73       54     72  667
# 736      507   86      68       72      109       66    106  668
# 799      600   80     110      120      130       90     70  721
#
#                           Name Type 1    Type 2  Generation  Legendary
# 4                   Charmander   Fire       NaN           1      False
# 5                   Charmeleon   Fire       NaN           1      False
# 6                    Charizard   Fire    Flying           1      False
# 7    CharizardMega Charizard X   Fire    Dragon           1      False
# 8    CharizardMega Charizard Y   Fire    Flying           1      False
# 42                      Vulpix   Fire       NaN           1      False
# 43                   Ninetales   Fire       NaN           1      False
# 63                   Growlithe   Fire       NaN           1      False
# 64                    Arcanine   Fire       NaN           1      False
# 83                      Ponyta   Fire       NaN           1      False
# 84                    Rapidash   Fire       NaN           1      False
# 135                     Magmar   Fire       NaN           1      False
# 147                    Flareon   Fire       NaN           1      False
# 158                    Moltres   Fire    Flying           1       True
# 169                  Cyndaquil   Fire       NaN           2      False
# 170                    Quilava   Fire       NaN           2      False
# 171                 Typhlosion   Fire       NaN           2      False
# 236                     Slugma   Fire       NaN           2      False
# 237                   Magcargo   Fire      Rock           2      False
# 259                      Magby   Fire       NaN           2      False
# 263                      Entei   Fire       NaN           2       True
# 270                      Ho-oh   Fire    Flying           2       True
# 276                    Torchic   Fire       NaN           3      False
# 277                  Combusken   Fire  Fighting           3      False
# 278                   Blaziken   Fire  Fighting           3      False
# 279      BlazikenMega Blaziken   Fire  Fighting           3      False
# 352                      Numel   Fire    Ground           3      False
# 353                   Camerupt   Fire    Ground           3      False
# 354      CameruptMega Camerupt   Fire    Ground           3      False
# 355                    Torkoal   Fire       NaN           3      False
# 435                   Chimchar   Fire       NaN           4      False
# 436                   Monferno   Fire  Fighting           4      False
# 437                  Infernape   Fire  Fighting           4      False
# 518                  Magmortar   Fire       NaN           4      False
# 542                    Heatran   Fire     Steel           4       True
# 557                      Tepig   Fire       NaN           5      False
# 558                    Pignite   Fire  Fighting           5      False
# 559                     Emboar   Fire  Fighting           5      False
# 572                    Pansear   Fire       NaN           5      False
# 573                   Simisear   Fire       NaN           5      False
# 614                   Darumaka   Fire       NaN           5      False
# 615    DarmanitanStandard Mode   Fire       NaN           5      False
# 616         DarmanitanZen Mode   Fire   Psychic           5      False
# 692                    Heatmor   Fire       NaN           5      False
# 721                   Fennekin   Fire       NaN           6      False
# 722                    Braixen   Fire       NaN           6      False
# 723                    Delphox   Fire   Psychic           6      False
# 730                Fletchinder   Fire    Flying           6      False
# 731                 Talonflame   Fire    Flying           6      False
# 735                     Litleo   Fire    Normal           6      False
# 736                     Pyroar   Fire    Normal           6      False
# 799                  Volcanion   Fire     Water           6       True

# %% [markdown]
# Let's make all Fire Pokemon Legendary

# %%
df.loc[df['Type 1'] == 'Fire', 'Legendary'] = True
df.loc[df['Legendary'] == True]
# Out:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 4        309  39      52       43       60       50     65    4
# 5        405  58      64       58       80       65     80    5
# 6        534  78      84       78      109       85    100    6
# 7        634  78     130      111      130       85    100    6
# 8        634  78     104       78      159      115    100    6
# ..       ...  ..     ...      ...      ...      ...    ...  ...
# 795      600  50     100      150      100      150     50  719
# 796      700  50     160      110      160      110    110  719
# 797      600  80     110       60      150      130     70  720
# 798      680  80     160       60      170      130     80  720
# 799      600  80     110      120      130       90     70  721
#
#                           Name   Type 1  Type 2  Generation  Legendary
# 4                   Charmander     Fire     NaN           1       True
# 5                   Charmeleon     Fire     NaN           1       True
# 6                    Charizard     Fire  Flying           1       True
# 7    CharizardMega Charizard X     Fire  Dragon           1       True
# 8    CharizardMega Charizard Y     Fire  Flying           1       True
# ..                         ...      ...     ...         ...        ...
# 795                    Diancie     Rock   Fairy           6       True
# 796        DiancieMega Diancie     Rock   Fairy           6       True
# 797        HoopaHoopa Confined  Psychic   Ghost           6       True
# 798         HoopaHoopa Unbound  Psychic    Dark           6       True
# 799                  Volcanion     Fire   Water           6       True
#
# [112 rows x 13 columns]

# %%
# Reverting changes
df = pd.read_csv('modified_pokemon_df.csv')
df.head()
# Out:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 0      318  45      49       49       65       65     45  1
# 1      405  60      62       63       80       80     60  2
# 2      525  80      82       83      100      100     80  3
# 3      625  80     100      123      122      120     80  3
# 4      309  39      52       43       60       50     65  4
#
#                     Name Type 1  Type 2  Generation  Legendary
# 0              Bulbasaur  Grass  Poison           1      False
# 1                Ivysaur  Grass  Poison           1      False
# 2               Venusaur  Grass  Poison           1      False
# 3  VenusaurMega Venusaur  Grass  Poison           1      False
# 4             Charmander   Fire     NaN           1      False

# %% [markdown]
# Multiple parameter changes

# %%
df.loc[df['Totalv2'] >= 600, ['Generation', 'Legendary']] = 'FLOW'
df.loc[df['Totalv2'] >= 600]
# Out:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 3        625  80     100      123      122      120     80    3
# 7        634  78     130      111      130       85    100    6
# 8        634  78     104       78      159      115    100    6
# 12       630  79     103      120      135      115     78    9
# 102      600  60      65       80      170       95    130   94
# ..       ...  ..     ...      ...      ...      ...    ...  ...
# 795      600  50     100      150      100      150     50  719
# 796      700  50     160      110      160      110    110  719
# 797      600  80     110       60      150      130     70  720
# 798      680  80     160       60      170      130     80  720
# 799      600  80     110      120      130       90     70  721
#
#                           Name   Type 1  Type 2 Generation Legendary
# 3        VenusaurMega Venusaur    Grass  Poison       FLOW      FLOW
# 7    CharizardMega Charizard X     Fire  Dragon       FLOW      FLOW
# 8    CharizardMega Charizard Y     Fire  Flying       FLOW      FLOW
# 12     BlastoiseMega Blastoise    Water     NaN       FLOW      FLOW
# 102          GengarMega Gengar    Ghost  Poison       FLOW      FLOW
# ..                         ...      ...     ...        ...       ...
# 795                    Diancie     Rock   Fairy       FLOW      FLOW
# 796        DiancieMega Diancie     Rock   Fairy       FLOW      FLOW
# 797        HoopaHoopa Confined  Psychic   Ghost       FLOW      FLOW
# 798         HoopaHoopa Unbound  Psychic    Dark       FLOW      FLOW
# 799                  Volcanion     Fire   Water       FLOW      FLOW
#
# [85 rows x 13 columns]

# %% [markdown]
# A more correct approach

# %%
df.loc[df['Totalv2'] >= 600, ['Generation', 'Legendary']] = ['100', True]
df.loc[df['Totalv2'] >= 600]
# Out:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 3        625  80     100      123      122      120     80    3
# 7        634  78     130      111      130       85    100    6
# 8        634  78     104       78      159      115    100    6
# 12       630  79     103      120      135      115     78    9
# 102      600  60      65       80      170       95    130   94
# ..       ...  ..     ...      ...      ...      ...    ...  ...
# 795      600  50     100      150      100      150     50  719
# 796      700  50     160      110      160      110    110  719
# 797      600  80     110       60      150      130     70  720
# 798      680  80     160       60      170      130     80  720
# 799      600  80     110      120      130       90     70  721
#
#                           Name   Type 1  Type 2 Generation Legendary
# 3        VenusaurMega Venusaur    Grass  Poison        100      True
# 7    CharizardMega Charizard X     Fire  Dragon        100      True
# 8    CharizardMega Charizard Y     Fire  Flying        100      True
# 12     BlastoiseMega Blastoise    Water     NaN        100      True
# 102          GengarMega Gengar    Ghost  Poison        100      True
# ..                         ...      ...     ...        ...       ...
# 795                    Diancie     Rock   Fairy        100      True
# 796        DiancieMega Diancie     Rock   Fairy        100      True
# 797        HoopaHoopa Confined  Psychic   Ghost        100      True
# 798         HoopaHoopa Unbound  Psychic    Dark        100      True
# 799                  Volcanion     Fire   Water        100      True
#
# [85 rows x 13 columns]

# %%
df.loc[df['Name'] == 'Dragonite']
# Out:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 161      600  91     134       95      100      100     80  149  Dragonite
#
#      Type 1  Type 2 Generation Legendary
# 161  Dragon  Flying        100      True

# %% [markdown]
# Advanced conditional Filtering with Regular Expressions (RegEx); lets change all pokemon whose name start with pi to the legendary status of PIKA PIKA

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.IGNORECASE, regex=True), 'Legendary'] = 'PIKA PIKA'
df.loc[df['Legendary'] == 'PIKA PIKA']
# Out:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 20       251   40      45       40       35       35     56   16
# 21       349   63      60       55       50       50     71   17
# 22       479   83      80       75       70       70    101   18
# 23       579   83      80       80      135       80    121   18
# 30       320   35      55       40       50       50     90   25
# 136      500   65     125      100       55       70     85  127
# 137      600   65     155      120       65       90    105  127
# 186      205   20      40       15       35       35     60  172
# 219      290   50      65       90       35       35     15  204
# 239      450  100     100       80       60       60     50  221
# 438      314   53      51       53       61       56     40  393
# 558      418   90      93       55       70       55     55  499
# 578      264   50      55       50       36       30     43  519
#
#                     Name    Type 1    Type 2 Generation  Legendary
# 20                Pidgey    Normal    Flying          1  PIKA PIKA
# 21             Pidgeotto    Normal    Flying          1  PIKA PIKA
# 22               Pidgeot    Normal    Flying          1  PIKA PIKA
# 23   PidgeotMega Pidgeot    Normal    Flying          1  PIKA PIKA
# 30               Pikachu  Electric       NaN          1  PIKA PIKA
# 136               Pinsir       Bug       NaN          1  PIKA PIKA
# 137    PinsirMega Pinsir       Bug    Flying        100  PIKA PIKA
# 186                Pichu  Electric       NaN          2  PIKA PIKA
# 219               Pineco       Bug       NaN          2  PIKA PIKA
# 239            Piloswine       Ice    Ground          2  PIKA PIKA
# 438               Piplup     Water       NaN          4  PIKA PIKA
# 558              Pignite      Fire  Fighting          5  PIKA PIKA
# 578               Pidove    Normal    Flying          5  PIKA PIKA

# %%
# Reverting changes
df = pd.read_csv('modified_pokemon_df.csv')
df.head()
# Out:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 0      318  45      49       49       65       65     45  1
# 1      405  60      62       63       80       80     60  2
# 2      525  80      82       83      100      100     80  3
# 3      625  80     100      123      122      120     80  3
# 4      309  39      52       43       60       50     65  4
#
#                     Name Type 1  Type 2  Generation  Legendary
# 0              Bulbasaur  Grass  Poison           1      False
# 1                Ivysaur  Grass  Poison           1      False
# 2               Venusaur  Grass  Poison           1      False
# 3  VenusaurMega Venusaur  Grass  Poison           1      False
# 4             Charmander   Fire     NaN           1      False

# %% [markdown]
# ## Aggregate statistics
#
# Group by, SUM, MIN, MAX, COUNT, AVG

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
# C:\Users\Brahyam Almonte Ruiz\AppData\Local\Temp\ipykernel_29468\3320615934.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
#              Totalv2         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Dragon    550.531250  83.312500  112.125000   86.375000  96.843750  88.843750
# Normal    401.683673  77.275510   73.469388   59.846939  55.816327  63.724490
# Fairy     413.176471  74.117647   61.529412   65.705882  78.529412  84.705882
# Ground    437.500000  73.781250   95.750000   84.843750  56.468750  62.750000
# Water     430.455357  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       433.458333  72.000000   72.750000   71.416667  77.541667  76.291667
# Flying    485.000000  70.750000   78.750000   66.250000  94.250000  72.500000
# Psychic   475.947368  70.631579   71.456140   67.684211  98.403509  86.280702
# Fire      458.076923  69.903846   84.769231   67.769231  88.980769  72.211538
# Fighting  416.444444  69.851852   96.777778   65.925926  53.111111  64.703704
# Grass     421.142857  67.271429   73.214286   70.800000  77.500000  70.428571
# Poison    399.142857  67.250000   74.678571   68.821429  60.428571  64.392857
# Dark      445.741935  66.806452   88.387097   70.225806  74.645161  69.516129
# Rock      453.750000  65.363636   92.863636  100.795455  63.340909  75.477273
# Steel     487.703704  65.222222   92.703704  126.370370  67.518519  80.629630
# Ghost     439.562500  64.437500   73.781250   81.187500  79.343750  76.468750
# Electric  443.409091  59.795455   69.090909   66.295455  90.022727  73.704545
# Bug       378.927536  56.884058   70.971014   70.724638  53.869565  64.797101
#
#                Speed           #  Generation  Legendary
# Type 1
# Dragon     83.031250  474.375000    3.875000   0.375000
# Normal     71.551020  319.173469    3.051020   0.020408
# Fairy      48.588235  449.529412    4.117647   0.058824
# Ground     63.906250  356.281250    3.156250   0.125000
# Water      65.964286  303.089286    2.857143   0.035714
# Ice        63.458333  423.541667    3.541667   0.083333
# Flying    102.500000  677.750000    5.500000   0.500000
# Psychic    81.491228  380.807018    3.385965   0.245614
# Fire       74.442308  327.403846    3.211538   0.096154
# Fighting   66.074074  363.851852    3.370370   0.000000
# Grass      61.928571  344.871429    3.357143   0.042857
# Poison     63.571429  251.785714    2.535714   0.000000
# Dark       76.161290  461.354839    4.032258   0.064516
# Rock       55.909091  392.727273    3.454545   0.090909
# Steel      55.259259  442.851852    3.851852   0.148148
# Ghost      64.343750  486.500000    4.187500   0.062500
# Electric   84.500000  363.500000    3.272727   0.090909
# Bug        61.681159  334.492754    3.217391   0.000000

# %% [markdown]
# Next, a cool SUM, but its not useful because we re adding only by the first type of a pokemon

# %%
df.groupby(['Type 1']).sum(numeric_only=True)
# Out:
#           Totalv2    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed      #  \
# Type 1
# Bug         26146  3925    4897     4880     3717     4471   4256  23080
# Dark        13818  2071    2740     2177     2314     2155   2361  14302
# Dragon      17617  2666    3588     2764     3099     2843   2657  15180
# Electric    19510  2631    3040     2917     3961     3243   3718  15994
# Fairy        7024  1260    1046     1117     1335     1440    826   7642
# Fighting    11244  1886    2613     1780     1434     1747   1784   9824
# Fire        23820  3635    4408     3524     4627     3755   3871  17025
# Flying       1940   283     315      265      377      290    410   2711
# Ghost       14066  2062    2361     2598     2539     2447   2059  15568
# Grass       29480  4709    5125     4956     5425     4930   4335  24141
# Ground      14000  2361    3064     2715     1807     2008   2045  11401
# Ice         10403  1728    1746     1714     1861     1831   1523  10165
# Normal      39365  7573    7200     5865     5470     6245   7012  31279
# Poison      11176  1883    2091     1927     1692     1803   1780   7050
# Psychic     27129  4026    4073     3858     5609     4918   4645  21706
# Rock        19965  2876    4086     4435     2787     3321   2460  17280
# Steel       13168  1761    2503     3412     1823     2177   1492  11957
# Water       48211  8071    8305     8170     8379     7898   7388  33946
#
#           Generation  Legendary
# Type 1
# Bug              222          0
# Dark             125          2
# Dragon           124         12
# Electric         144          4
# Fairy             70          1
# Fighting          91          0
# Fire             167          5
# Flying            22          2
# Ghost            134          2
# Grass            235          3
# Ground           101          4
# Ice               85          2
# Normal           299          2
# Poison            71          0
# Psychic          193         14
# Rock             152          4
# Steel            104          4
# Water            320          4

# %% [markdown]
# Count method

# %%
df.groupby('Legendary').count()
# Out:
#            Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  Name  \
# Legendary
# False          735  735     735      735      735      735    735  735   735
# True            65   65      65       65       65       65     65   65    65
#
#            Type 1  Type 2  Generation
# Legendary
# False         735     374         735
# True           65      40          65

# %% [markdown]
# Now let's count again, we can see the rows have the same data in each of its columns, except the Type 2 column, this one only got 52 entries in the first row.
#
# That's because there's some pokemon that are pure bug, meaning they have 'Bug' in Type 1 and BLANK or NULL in Type 2

# %%
df.groupby('Type 1').count()
# Out:
#           Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  Name  \
# Type 1
# Bug            69   69      69       69       69       69     69   69    69
# Dark           31   31      31       31       31       31     31   31    31
# Dragon         32   32      32       32       32       32     32   32    32
# Electric       44   44      44       44       44       44     44   44    44
# Fairy          17   17      17       17       17       17     17   17    17
# Fighting       27   27      27       27       27       27     27   27    27
# Fire           52   52      52       52       52       52     52   52    52
# Flying          4    4       4        4        4        4      4    4     4
# Ghost          32   32      32       32       32       32     32   32    32
# Grass          70   70      70       70       70       70     70   70    70
# Ground         32   32      32       32       32       32     32   32    32
# Ice            24   24      24       24       24       24     24   24    24
# Normal         98   98      98       98       98       98     98   98    98
# Poison         28   28      28       28       28       28     28   28    28
# Psychic        57   57      57       57       57       57     57   57    57
# Rock           44   44      44       44       44       44     44   44    44
# Steel          27   27      27       27       27       27     27   27    27
# Water         112  112     112      112      112      112    112  112   112
#
#           Type 2  Generation  Legendary
# Type 1
# Bug           52          69         69
# Dark          21          31         31
# Dragon        21          32         32
# Electric      17          44         44
# Fairy          2          17         17
# Fighting       7          27         27
# Fire          24          52         52
# Flying         2           4          4
# Ghost         22          32         32
# Grass         37          70         70
# Ground        19          32         32
# Ice           11          24         24
# Normal        37          98         98
# Poison        13          28         28
# Psychic       19          57         57
# Rock          35          44         44
# Steel         22          27         27
# Water         53         112        112

# %% [markdown]
# Now lets count, but only output one column of the new dataframe,

# %%
df.groupby('Type 1').count()['Name']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: Name, dtype: int64

# %% [markdown]
# Now lets try to do it but with two columns

# %%
df.groupby('Type 1').count()[['Name', 'Type 2']]
# Out:
#           Name  Type 2
# Type 1
# Bug         69      52
# Dark        31      21
# Dragon      32      21
# Electric    44      17
# Fairy       17       2
# Fighting    27       7
# Fire        52      24
# Flying       4       2
# Ghost       32      22
# Grass       70      37
# Ground      32      19
# Ice         24      11
# Normal      98      37
# Poison      28      13
# Psychic     57      19
# Rock        44      35
# Steel       27      22
# Water      112      53

# %% [markdown]
# Now lets group by multiples values

# %%
# Note: only one column outputs a dictionary of sorts
df.groupby(['Type 1', 'Type 2']).count()['Name']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: Name, Length: 136, dtype: int64

# %%
# But two columns output a dataframe
df.groupby(['Type 1', 'Type 2']).count()[['Name', '#']]
# Out:
#                  Name   #
# Type 1 Type 2
# Bug    Electric     2   2
#        Fighting     2   2
#        Fire         2   2
#        Flying      14  14
#        Ghost        1   1
# ...               ...  ..
# Water  Ice          3   3
#        Poison       3   3
#        Psychic      5   5
#        Rock         4   4
#        Steel        1   1
#
# [136 rows x 2 columns]

# %% [markdown]
# Working with large amounts of data, like a 10GB file

# %%
# This would be a normal, total read
df = pd.read_csv('modified_pokemon_df.csv')

# %%
# This line reads the file in batches of 5 rows
df = pd.read_csv('modified_pokemon_df.csv', chunksize=5)

# %% [markdown]
# Now lets make sure is reading chunk by chunk

# %%
i = 0
for df in pd.read_csv('modified_pokemon_df.csv', chunksize=10):
    i += 1
    print('Current Batch:', i)
# Out:
# Current Batch: 1
# Current Batch: 2
# Current Batch: 3
# Current Batch: 4
# Current Batch: 5
# Current Batch: 6
# Current Batch: 7
# Current Batch: 8
# Current Batch: 9
# Current Batch: 10
# Current Batch: 11
# Current Batch: 12
# Current Batch: 13
# Current Batch: 14
# Current Batch: 15
# Current Batch: 16
# Current Batch: 17
# Current Batch: 18
# Current Batch: 19
# Current Batch: 20
# Current Batch: 21
# Current Batch: 22
# Current Batch: 23
# Current Batch: 24
# Current Batch: 25
# Current Batch: 26
# Current Batch: 27
# Current Batch: 28
# Current Batch: 29
# Current Batch: 30
# Current Batch: 31
# Current Batch: 32
# Current Batch: 33
# Current Batch: 34
# Current Batch: 35
# Current Batch: 36
# Current Batch: 37
# Current Batch: 38
# Current Batch: 39
# Current Batch: 40
# Current Batch: 41
# Current Batch: 42
# Current Batch: 43
# Current Batch: 44
# Current Batch: 45
# Current Batch: 46
# Current Batch: 47
# Current Batch: 48
# Current Batch: 49
# Current Batch: 50
# Current Batch: 51
# Current Batch: 52
# Current Batch: 53
# Current Batch: 54
# Current Batch: 55
# Current Batch: 56
# Current Batch: 57
# Current Batch: 58
# Current Batch: 59
# Current Batch: 60
# Current Batch: 61
# Current Batch: 62
# Current Batch: 63
# Current Batch: 64
# Current Batch: 65
# Current Batch: 66
# Current Batch: 67
# Current Batch: 68
# Current Batch: 69
# Current Batch: 70
# Current Batch: 71
# Current Batch: 72
# Current Batch: 73
# Current Batch: 74
# Current Batch: 75
# Current Batch: 76
# Current Batch: 77
# Current Batch: 78
# Current Batch: 79
# Current Batch: 80

# %%
# Another way to confirm this is working
for df in pd.read_csv('modified_pokemon_df.csv', chunksize=2):
    print('Current Batch:')
    print(df)
# Out:
# Current Batch:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #       Name Type 1  \
# 0      318  45      49       49       65       65     45  1  Bulbasaur  Grass
# 1      405  60      62       63       80       80     60  2    Ivysaur  Grass
#
#    Type 2  Generation  Legendary
# 0  Poison           1      False
# 1  Poison           1      False
# Current Batch:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 2      525  80      82       83      100      100     80  3
# 3      625  80     100      123      122      120     80  3
#
#                     Name Type 1  Type 2  Generation  Legendary
# 2               Venusaur  Grass  Poison           1      False
# 3  VenusaurMega Venusaur  Grass  Poison           1      False
# Current Batch:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #        Name  \
# 4      309  39      52       43       60       50     65  4  Charmander
# 5      405  58      64       58       80       65     80  5  Charmeleon
#
#   Type 1  Type 2  Generation  Legendary
# 4   Fire     NaN           1      False
# 5   Fire     NaN           1      False
# Current Batch:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 6      534  78      84       78      109       85    100  6
# 7      634  78     130      111      130       85    100  6
#
#                         Name Type 1  Type 2  Generation  Legendary
# 6                  Charizard   Fire  Flying           1      False
# 7  CharizardMega Charizard X   Fire  Dragon           1      False
# Current Batch:
#    Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #  \
# 8      634  78     104       78      159      115    100  6
# 9      314  44      48       65       50       64     43  7
#
#                         Name Type 1  Type 2  Generation  Legendary
# 8  CharizardMega Charizard Y   Fire  Flying           1      False
# 9                   Squirtle  Water     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  #       Name  \
# 10      405  59      63       80       65       80     58  8  Wartortle
# 11      530  79      83      100       85      105     78  9  Blastoise
#
#    Type 1  Type 2  Generation  Legendary
# 10  Water     NaN           1      False
# 11  Water     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 12      630  79     103      120      135      115     78   9
# 13      195  45      30       35       20       20     45  10
#
#                        Name Type 1  Type 2  Generation  Legendary
# 12  BlastoiseMega Blastoise  Water     NaN           1      False
# 13                 Caterpie    Bug     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 14      205  50      20       55       25       25     30  11     Metapod
# 15      395  60      45       50       90       80     70  12  Butterfree
#
#    Type 1  Type 2  Generation  Legendary
# 14    Bug     NaN           1      False
# 15    Bug  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #    Name Type 1  \
# 16      195  40      35       30       20       20     50  13  Weedle    Bug
# 17      205  45      25       50       25       25     35  14  Kakuna    Bug
#
#     Type 2  Generation  Legendary
# 16  Poison           1      False
# 17  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 18      395  65      90       40       45       80     75  15
# 19      495  65     150       40       15       80    145  15
#
#                      Name Type 1  Type 2  Generation  Legendary
# 18               Beedrill    Bug  Poison           1      False
# 19  BeedrillMega Beedrill    Bug  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 20      251  40      45       40       35       35     56  16     Pidgey
# 21      349  63      60       55       50       50     71  17  Pidgeotto
#
#     Type 1  Type 2  Generation  Legendary
# 20  Normal  Flying           1      False
# 21  Normal  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 22      479  83      80       75       70       70    101  18
# 23      579  83      80       80      135       80    121  18
#
#                    Name  Type 1  Type 2  Generation  Legendary
# 22              Pidgeot  Normal  Flying           1      False
# 23  PidgeotMega Pidgeot  Normal  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 24      253  30      56       35       25       35     72  19   Rattata
# 25      413  55      81       60       50       70     97  20  Raticate
#
#     Type 1  Type 2  Generation  Legendary
# 24  Normal     NaN           1      False
# 25  Normal     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 26      262  40      60       30       31       31     70  21  Spearow
# 27      442  65      90       65       61       61    100  22   Fearow
#
#     Type 1  Type 2  Generation  Legendary
# 26  Normal  Flying           1      False
# 27  Normal  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #   Name  Type 1  \
# 28      288  35      60       44       40       54     55  23  Ekans  Poison
# 29      438  60      85       69       65       79     80  24  Arbok  Poison
#
#     Type 2  Generation  Legendary
# 28     NaN           1      False
# 29     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 30      320  35      55       40       50       50     90  25  Pikachu
# 31      485  60      90       55       90       80    110  26   Raichu
#
#       Type 1  Type 2  Generation  Legendary
# 30  Electric     NaN           1      False
# 31  Electric     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 32      300  50      75       85       20       30     40  27  Sandshrew
# 33      450  75     100      110       45       55     65  28  Sandslash
#
#     Type 1  Type 2  Generation  Legendary
# 32  Ground     NaN           1      False
# 33  Ground     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 34      275  55      47       52       40       40     41  29
# 35      365  70      62       67       55       55     56  30
#
#                 Name  Type 1  Type 2  Generation  Legendary
# 34  Nidoran (Female)  Poison     NaN           1      False
# 35          Nidorina  Poison     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #            Name  \
# 36      505  90      92       87       75       85     76  31       Nidoqueen
# 37      273  46      57       40       40       40     50  32  Nidoran (Male)
#
#     Type 1  Type 2  Generation  Legendary
# 36  Poison  Ground           1      False
# 37  Poison     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 38      365  61      72       57       55       55     65  33  Nidorino
# 39      505  81     102       77       85       75     85  34  Nidoking
#
#     Type 1  Type 2  Generation  Legendary
# 38  Poison     NaN           1      False
# 39  Poison  Ground           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 40      323  70      45       48       60       65     35  35  Clefairy
# 41      483  95      70       73       95       90     60  36  Clefable
#
#    Type 1  Type 2  Generation  Legendary
# 40  Fairy     NaN           1      False
# 41  Fairy     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 42      299  38      41       40       50       65     65  37     Vulpix
# 43      505  73      76       75       81      100    100  38  Ninetales
#
#    Type 1  Type 2  Generation  Legendary
# 42   Fire     NaN           1      False
# 43   Fire     NaN           1      False
# Current Batch:
#     Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 44      270  115      45       20       45       25     20  39  Jigglypuff
# 45      435  140      70       45       85       50     45  40  Wigglytuff
#
#     Type 1 Type 2  Generation  Legendary
# 44  Normal  Fairy           1      False
# 45  Normal  Fairy           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #    Name  Type 1  \
# 46      245  40      45       35       30       40     55  41   Zubat  Poison
# 47      455  75      80       70       65       75     90  42  Golbat  Poison
#
#     Type 2  Generation  Legendary
# 46  Flying           1      False
# 47  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #    Name Type 1  \
# 48      320  45      50       55       75       65     30  43  Oddish  Grass
# 49      395  60      65       70       85       75     40  44   Gloom  Grass
#
#     Type 2  Generation  Legendary
# 48  Poison           1      False
# 49  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 50      490  75      80       85      110       90     50  45  Vileplume
# 51      285  35      70       55       45       55     25  46      Paras
#
#    Type 1  Type 2  Generation  Legendary
# 50  Grass  Poison           1      False
# 51    Bug   Grass           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 52      405  60      95       80       60       80     30  47  Parasect
# 53      305  60      55       50       40       55     45  48   Venonat
#
#    Type 1  Type 2  Generation  Legendary
# 52    Bug   Grass           1      False
# 53    Bug  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 54      450  70      65       60       90       75     90  49  Venomoth
# 55      265  10      55       25       35       45     95  50   Diglett
#
#     Type 1  Type 2  Generation  Legendary
# 54     Bug  Poison           1      False
# 55  Ground     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 56      405  35      80       50       50       70    120  51  Dugtrio
# 57      290  40      45       35       40       40     90  52   Meowth
#
#     Type 1  Type 2  Generation  Legendary
# 56  Ground     NaN           1      False
# 57  Normal     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 58      440  65      70       60       65       65    115  53  Persian
# 59      320  50      52       48       65       50     55  54  Psyduck
#
#     Type 1  Type 2  Generation  Legendary
# 58  Normal     NaN           1      False
# 59   Water     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 60      500  80      82       78       95       80     85  55  Golduck
# 61      305  40      80       35       35       45     70  56   Mankey
#
#       Type 1  Type 2  Generation  Legendary
# 60     Water     NaN           1      False
# 61  Fighting     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 62      455  65     105       60       60       70     95  57   Primeape
# 63      350  55      70       45       70       50     60  58  Growlithe
#
#       Type 1  Type 2  Generation  Legendary
# 62  Fighting     NaN           1      False
# 63      Fire     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 64      555  90     110       80      100       80     95  59  Arcanine
# 65      300  40      50       40       40       40     90  60   Poliwag
#
#    Type 1  Type 2  Generation  Legendary
# 64   Fire     NaN           1      False
# 65  Water     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 66      385  65      65       65       50       50     90  61  Poliwhirl
# 67      510  90      95       95       70       90     70  62  Poliwrath
#
#    Type 1    Type 2  Generation  Legendary
# 66  Water       NaN           1      False
# 67  Water  Fighting           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 68      310  25      20       15      105       55     90  63     Abra
# 69      400  40      35       30      120       70    105  64  Kadabra
#
#      Type 1  Type 2  Generation  Legendary
# 68  Psychic     NaN           1      False
# 69  Psychic     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 70      500  55      50       45      135       95    120  65
# 71      590  55      50       65      175       95    150  65
#
#                      Name   Type 1  Type 2  Generation  Legendary
# 70               Alakazam  Psychic     NaN           1      False
# 71  AlakazamMega Alakazam  Psychic     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 72      305  70      80       50       35       35     35  66   Machop
# 73      405  80     100       70       50       60     45  67  Machoke
#
#       Type 1  Type 2  Generation  Legendary
# 72  Fighting     NaN           1      False
# 73  Fighting     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 74      505  90     130       80       65       85     55  68     Machamp
# 75      300  50      75       35       70       30     40  69  Bellsprout
#
#       Type 1  Type 2  Generation  Legendary
# 74  Fighting     NaN           1      False
# 75     Grass  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 76      390  65      90       50       85       45     55  70  Weepinbell
# 77      490  80     105       65      100       70     70  71  Victreebel
#
#    Type 1  Type 2  Generation  Legendary
# 76  Grass  Poison           1      False
# 77  Grass  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 78      335  40      40       35       50      100     70  72   Tentacool
# 79      515  80      70       65       80      120    100  73  Tentacruel
#
#    Type 1  Type 2  Generation  Legendary
# 78  Water  Poison           1      False
# 79  Water  Poison           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 80      300  40      80      100       30       30     20  74   Geodude
# 81      390  55      95      115       45       45     35  75  Graveler
#
#    Type 1  Type 2  Generation  Legendary
# 80   Rock  Ground           1      False
# 81   Rock  Ground           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #    Name Type 1  \
# 82      495  80     120      130       55       65     45  76   Golem   Rock
# 83      410  50      85       55       65       65     90  77  Ponyta   Fire
#
#     Type 2  Generation  Legendary
# 82  Ground           1      False
# 83     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 84      500  65     100       70       80       80    105  78  Rapidash
# 85      315  90      65       65       40       40     15  79  Slowpoke
#
#    Type 1   Type 2  Generation  Legendary
# 84   Fire      NaN           1      False
# 85  Water  Psychic           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 86      490  95      75      110      100       80     30  80
# 87      590  95      75      180      130       80     30  80
#
#                    Name Type 1   Type 2  Generation  Legendary
# 86              Slowbro  Water  Psychic           1      False
# 87  SlowbroMega Slowbro  Water  Psychic           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #       Name  \
# 88      325  25      35       70       95       55     45  81  Magnemite
# 89      465  50      60       95      120       70     70  82   Magneton
#
#       Type 1 Type 2  Generation  Legendary
# 88  Electric  Steel           1      False
# 89  Electric  Steel           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #        Name  \
# 90      352  52      65       55       58       62     60  83  Farfetch'd
# 91      310  35      85       45       35       35     75  84       Doduo
#
#     Type 1  Type 2  Generation  Legendary
# 90  Normal  Flying           1      False
# 91  Normal  Flying           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #    Name  Type 1  \
# 92      460  60     110       70       60       60    100  85  Dodrio  Normal
# 93      325  65      45       55       45       70     45  86    Seel   Water
#
#     Type 2  Generation  Legendary
# 92  Flying           1      False
# 93     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 94      475  90      70       80       70       95     70  87  Dewgong
# 95      325  80      80       50       40       50     25  88   Grimer
#
#     Type 1 Type 2  Generation  Legendary
# 94   Water    Ice           1      False
# 95  Poison    NaN           1      False
# Current Batch:
#     Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 96      500  105     105       75       65      100     50  89       Muk
# 97      305   30      65      100       45       25     40  90  Shellder
#
#     Type 1  Type 2  Generation  Legendary
# 96  Poison     NaN           1      False
# 97   Water     NaN           1      False
# Current Batch:
#     Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #      Name  \
# 98      525  50      95      180       85       45     70  91  Cloyster
# 99      310  30      35       30      100       35     80  92    Gastly
#
#    Type 1  Type 2  Generation  Legendary
# 98  Water     Ice           1      False
# 99  Ghost  Poison           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 100      405  45      50       45      115       55     95  93  Haunter
# 101      500  60      65       60      130       75    110  94   Gengar
#
#     Type 1  Type 2  Generation  Legendary
# 100  Ghost  Poison           1      False
# 101  Ghost  Poison           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #  \
# 102      600  60      65       80      170       95    130  94
# 103      385  35      45      160       30       45     70  95
#
#                   Name Type 1  Type 2  Generation  Legendary
# 102  GengarMega Gengar  Ghost  Poison           1      False
# 103               Onix   Rock  Ground           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 104      328  60      48       45       43       90     42  96  Drowzee
# 105      483  85      73       70       73      115     67  97    Hypno
#
#       Type 1  Type 2  Generation  Legendary
# 104  Psychic     NaN           1      False
# 105  Psychic     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed   #     Name  \
# 106      325  30     105       90       25       25     50  98   Krabby
# 107      475  55     130      115       50       50     75  99  Kingler
#
#     Type 1  Type 2  Generation  Legendary
# 106  Water     NaN           1      False
# 107  Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 108      330  40      30       50       55       55    100  100    Voltorb
# 109      480  60      50       70       80       80    140  101  Electrode
#
#        Type 1  Type 2  Generation  Legendary
# 108  Electric     NaN           1      False
# 109  Electric     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 110      325  60      40       80       60       45     40  102  Exeggcute
# 111      520  95      95       85      125       65     55  103  Exeggutor
#
#     Type 1   Type 2  Generation  Legendary
# 110  Grass  Psychic           1      False
# 111  Grass  Psychic           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 112      320  50      50       95       40       50     35  104   Cubone
# 113      425  60      80      110       50       80     45  105  Marowak
#
#      Type 1  Type 2  Generation  Legendary
# 112  Ground     NaN           1      False
# 113  Ground     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 114      455  50     120       53       35      110     87  106   Hitmonlee
# 115      455  50     105       79       35      110     76  107  Hitmonchan
#
#        Type 1  Type 2  Generation  Legendary
# 114  Fighting     NaN           1      False
# 115  Fighting     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 116      385  90      55       75       60       75     30  108  Lickitung
# 117      340  40      65       95       60       45     35  109    Koffing
#
#      Type 1  Type 2  Generation  Legendary
# 116  Normal     NaN           1      False
# 117  Poison     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 118      490  65      90      120       85       70     60  110  Weezing
# 119      345  80      85       95       30       30     25  111  Rhyhorn
#
#      Type 1 Type 2  Generation  Legendary
# 118  Poison    NaN           1      False
# 119  Ground   Rock           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 120      485  105     130      120       45       45     40  112   Rhydon
# 121      450  250       5        5       35      105     50  113  Chansey
#
#      Type 1 Type 2  Generation  Legendary
# 120  Ground   Rock           1      False
# 121  Normal    NaN           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 122      435   65      55      115      100       40     60  114     Tangela
# 123      490  105      95       80       40       80     90  115  Kangaskhan
#
#      Type 1  Type 2  Generation  Legendary
# 122   Grass     NaN           1      False
# 123  Normal     NaN           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 124      590  105     125      100       60      100    100  115
# 125      295   30      40       70       70       25     60  116
#
#                           Name  Type 1  Type 2  Generation  Legendary
# 124  KangaskhanMega Kangaskhan  Normal     NaN           1      False
# 125                     Horsea   Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 126      440  55      65       95       95       45     85  117   Seadra
# 127      320  45      67       60       35       50     63  118  Goldeen
#
#     Type 1  Type 2  Generation  Legendary
# 126  Water     NaN           1      False
# 127  Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 128      450  80      92       65       65       80     68  119  Seaking
# 129      340  30      45       55       70       55     85  120   Staryu
#
#     Type 1  Type 2  Generation  Legendary
# 128  Water     NaN           1      False
# 129  Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 130      520  60      75       85      100       85    115  121   Starmie
# 131      460  40      45       65      100      120     90  122  Mr. Mime
#
#       Type 1   Type 2  Generation  Legendary
# 130    Water  Psychic           1      False
# 131  Psychic    Fairy           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 132      500  70     110       80       55       80    105  123  Scyther
# 133      455  65      50       35      115       95     95  124     Jynx
#
#     Type 1   Type 2  Generation  Legendary
# 132    Bug   Flying           1      False
# 133    Ice  Psychic           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 134      490  65      83       57       95       85    105  125  Electabuzz
# 135      495  65      95       57      100       85     93  126      Magmar
#
#        Type 1  Type 2  Generation  Legendary
# 134  Electric     NaN           1      False
# 135      Fire     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 136      500  65     125      100       55       70     85  127
# 137      600  65     155      120       65       90    105  127
#
#                   Name Type 1  Type 2  Generation  Legendary
# 136             Pinsir    Bug     NaN           1      False
# 137  PinsirMega Pinsir    Bug  Flying           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 138      490  75     100       95       40       70    110  128    Tauros
# 139      200  20      10       55       15       20     80  129  Magikarp
#
#      Type 1  Type 2  Generation  Legendary
# 138  Normal     NaN           1      False
# 139   Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 140      540  95     125       79       60      100     81  130
# 141      640  95     155      109       70      130     81  130
#
#                       Name Type 1  Type 2  Generation  Legendary
# 140               Gyarados  Water  Flying           1      False
# 141  GyaradosMega Gyarados  Water    Dark           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 142      535  130      85       80       85       95     60  131  Lapras
# 143      288   48      48       48       48       48     48  132   Ditto
#
#      Type 1 Type 2  Generation  Legendary
# 142   Water    Ice           1      False
# 143  Normal    NaN           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 144      325   55      55       50       45       65     55  133     Eevee
# 145      525  130      65       60      110       95     65  134  Vaporeon
#
#      Type 1  Type 2  Generation  Legendary
# 144  Normal     NaN           1      False
# 145   Water     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 146      525  65      65       60      110       95    130  135  Jolteon
# 147      525  65     130       60       95      110     65  136  Flareon
#
#        Type 1  Type 2  Generation  Legendary
# 146  Electric     NaN           1      False
# 147      Fire     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 148      395  65      60       70       85       75     40  137  Porygon
# 149      355  35      40      100       90       55     35  138  Omanyte
#
#      Type 1 Type 2  Generation  Legendary
# 148  Normal    NaN           1      False
# 149    Rock  Water           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 150      495  70      60      125      115       70     55  139  Omastar
# 151      355  30      80       90       55       45     55  140   Kabuto
#
#     Type 1 Type 2  Generation  Legendary
# 150   Rock  Water           1      False
# 151   Rock  Water           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 152      495  60     115      105       65       70     80  141    Kabutops
# 153      515  80     105       65       60       75    130  142  Aerodactyl
#
#     Type 1  Type 2  Generation  Legendary
# 152   Rock   Water           1      False
# 153   Rock  Flying           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 154      615   80     135       85       70       95    150  142
# 155      540  160     110       65       65      110     30  143
#
#                           Name  Type 1  Type 2  Generation  Legendary
# 154  AerodactylMega Aerodactyl    Rock  Flying           1      False
# 155                    Snorlax  Normal     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 156      580  90      85      100       95      125     85  144  Articuno
# 157      580  90      90       85      125       90    100  145    Zapdos
#
#        Type 1  Type 2  Generation  Legendary
# 156       Ice  Flying           1       True
# 157  Electric  Flying           1       True
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 158      580  90     100       90      125       85     90  146  Moltres
# 159      300  41      64       45       50       50     50  147  Dratini
#
#      Type 1  Type 2  Generation  Legendary
# 158    Fire  Flying           1       True
# 159  Dragon     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 160      420  61      84       65       70       70     70  148  Dragonair
# 161      600  91     134       95      100      100     80  149  Dragonite
#
#      Type 1  Type 2  Generation  Legendary
# 160  Dragon     NaN           1      False
# 161  Dragon  Flying           1      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 162      680  106     110       90      154       90    130  150
# 163      780  106     190      100      154      100    130  150
#
#                     Name   Type 1    Type 2  Generation  Legendary
# 162               Mewtwo  Psychic       NaN           1       True
# 163  MewtwoMega Mewtwo X  Psychic  Fighting           1       True
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 164      780  106     150       70      194      120    140  150
# 165      600  100     100      100      100      100    100  151
#
#                     Name   Type 1  Type 2  Generation  Legendary
# 164  MewtwoMega Mewtwo Y  Psychic     NaN           1       True
# 165                  Mew  Psychic     NaN           1      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 166      318  45      49       65       49       65     45  152  Chikorita
# 167      405  60      62       80       63       80     60  153    Bayleef
#
#     Type 1  Type 2  Generation  Legendary
# 166  Grass     NaN           2      False
# 167  Grass     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 168      525  80      82      100       83      100     80  154   Meganium
# 169      309  39      52       43       60       50     65  155  Cyndaquil
#
#     Type 1  Type 2  Generation  Legendary
# 168  Grass     NaN           2      False
# 169   Fire     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 170      405  58      64       58       80       65     80  156     Quilava
# 171      534  78      84       78      109       85    100  157  Typhlosion
#
#     Type 1  Type 2  Generation  Legendary
# 170   Fire     NaN           2      False
# 171   Fire     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 172      314  50      65       64       44       48     43  158  Totodile
# 173      405  65      80       80       59       63     58  159  Croconaw
#
#     Type 1  Type 2  Generation  Legendary
# 172  Water     NaN           2      False
# 173  Water     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 174      530  85     105      100       79       83     78  160  Feraligatr
# 175      215  35      46       34       35       45     20  161     Sentret
#
#      Type 1  Type 2  Generation  Legendary
# 174   Water     NaN           2      False
# 175  Normal     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 176      415  85      76       64       45       55     90  162    Furret
# 177      262  60      30       30       36       56     50  163  Hoothoot
#
#      Type 1  Type 2  Generation  Legendary
# 176  Normal     NaN           2      False
# 177  Normal  Flying           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 178      442  100      50       50       76       96     70  164  Noctowl
# 179      265   40      20       30       40       80     55  165   Ledyba
#
#      Type 1  Type 2  Generation  Legendary
# 178  Normal  Flying           2      False
# 179     Bug  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 180      390  55      35       50       55      110     85  166    Ledian
# 181      250  40      60       40       40       40     30  167  Spinarak
#
#     Type 1  Type 2  Generation  Legendary
# 180    Bug  Flying           2      False
# 181    Bug  Poison           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 182      390  70      90       70       60       60     40  168  Ariados
# 183      535  85      90       80       70       80    130  169   Crobat
#
#      Type 1  Type 2  Generation  Legendary
# 182     Bug  Poison           2      False
# 183  Poison  Flying           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 184      330   75      38       38       56       56     67  170  Chinchou
# 185      460  125      58       58       76       76     67  171   Lanturn
#
#     Type 1    Type 2  Generation  Legendary
# 184  Water  Electric           2      False
# 185  Water  Electric           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 186      205  20      40       15       35       35     60  172   Pichu
# 187      218  50      25       28       45       55     15  173  Cleffa
#
#        Type 1  Type 2  Generation  Legendary
# 186  Electric     NaN           2      False
# 187     Fairy     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 188      210  90      30       15       40       20     15  174  Igglybuff
# 189      245  35      20       65       40       65     20  175     Togepi
#
#      Type 1 Type 2  Generation  Legendary
# 188  Normal  Fairy           2      False
# 189   Fairy    NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 190      405  55      40       85       80      105     40  176  Togetic
# 191      320  40      50       45       70       45     70  177     Natu
#
#       Type 1  Type 2  Generation  Legendary
# 190    Fairy  Flying           2      False
# 191  Psychic  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 192      470  65      75       70       95       70     95  178    Xatu
# 193      280  55      40       40       65       45     35  179  Mareep
#
#        Type 1  Type 2  Generation  Legendary
# 192   Psychic  Flying           2      False
# 193  Electric     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 194      365  70      55       55       80       60     45  180   Flaaffy
# 195      510  90      75       85      115       90     55  181  Ampharos
#
#        Type 1  Type 2  Generation  Legendary
# 194  Electric     NaN           2      False
# 195  Electric     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 196      610  90      95      105      165      110     45  181
# 197      490  75      80       95       90      100     50  182
#
#                       Name    Type 1  Type 2  Generation  Legendary
# 196  AmpharosMega Ampharos  Electric  Dragon           2      False
# 197              Bellossom     Grass     NaN           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 198      250   70      20       50       20       50     40  183     Marill
# 199      420  100      50       80       60       80     50  184  Azumarill
#
#     Type 1 Type 2  Generation  Legendary
# 198  Water  Fairy           2      False
# 199  Water  Fairy           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 200      410  70     100      115       30       65     30  185  Sudowoodo
# 201      500  90      75       75       90      100     70  186   Politoed
#
#     Type 1  Type 2  Generation  Legendary
# 200   Rock     NaN           2      False
# 201  Water     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 202      250  35      35       40       35       55     50  187    Hoppip
# 203      340  55      45       50       45       65     80  188  Skiploom
#
#     Type 1  Type 2  Generation  Legendary
# 202  Grass  Flying           2      False
# 203  Grass  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 204      460  75      55       70       55       95    110  189  Jumpluff
# 205      360  55      70       55       40       55     85  190     Aipom
#
#      Type 1  Type 2  Generation  Legendary
# 204   Grass  Flying           2      False
# 205  Normal     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 206      180  30      30       30       30       30     30  191   Sunkern
# 207      425  75      75       55      105       85     30  192  Sunflora
#
#     Type 1  Type 2  Generation  Legendary
# 206  Grass     NaN           2      False
# 207  Grass     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 208      390  65      65       45       75       45     95  193   Yanma
# 209      210  55      45       45       25       25     15  194  Wooper
#
#     Type 1  Type 2  Generation  Legendary
# 208    Bug  Flying           2      False
# 209  Water  Ground           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 210      430  95      85       85       65       65     35  195  Quagsire
# 211      525  65      65       60      130       95    110  196    Espeon
#
#       Type 1  Type 2  Generation  Legendary
# 210    Water  Ground           2      False
# 211  Psychic     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 212      525  95      65      110       60      130     65  197  Umbreon
# 213      405  60      85       42       85       42     91  198  Murkrow
#
#     Type 1  Type 2  Generation  Legendary
# 212   Dark     NaN           2      False
# 213   Dark  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 214      490  95      75       80      100      110     30  199    Slowking
# 215      435  60      60       60       85       85     85  200  Misdreavus
#
#     Type 1   Type 2  Generation  Legendary
# 214  Water  Psychic           2      False
# 215  Ghost      NaN           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 216      336   48      72       48       72       48     48  201      Unown
# 217      405  190      33       58       33       58     33  202  Wobbuffet
#
#       Type 1  Type 2  Generation  Legendary
# 216  Psychic     NaN           2      False
# 217  Psychic     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 218      455  70      80       65       90       65     85  203  Girafarig
# 219      290  50      65       90       35       35     15  204     Pineco
#
#      Type 1   Type 2  Generation  Legendary
# 218  Normal  Psychic           2      False
# 219     Bug      NaN           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 220      465   75      90      140       60       60     40  205  Forretress
# 221      415  100      70       70       65       65     45  206   Dunsparce
#
#      Type 1 Type 2  Generation  Legendary
# 220     Bug  Steel           2      False
# 221  Normal    NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 222      430  65      75      105       35       65     85  207   Gligar
# 223      510  75      85      200       55       65     30  208  Steelix
#
#      Type 1  Type 2  Generation  Legendary
# 222  Ground  Flying           2      False
# 223   Steel  Ground           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 224      610  75     125      230       55       95     30  208
# 225      300  60      80       50       40       40     30  209
#
#                     Name Type 1  Type 2  Generation  Legendary
# 224  SteelixMega Steelix  Steel  Ground           2      False
# 225             Snubbull  Fairy     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 226      450  90     120       75       60       60     45  210  Granbull
# 227      430  65      95       75       55       55     85  211  Qwilfish
#
#     Type 1  Type 2  Generation  Legendary
# 226  Fairy     NaN           2      False
# 227  Water  Poison           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 228      500  70     130      100       55       80     65  212
# 229      600  70     150      140       65      100     75  212
#
#                   Name Type 1 Type 2  Generation  Legendary
# 228             Scizor    Bug  Steel           2      False
# 229  ScizorMega Scizor    Bug  Steel           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 230      505  20      10      230       10      230      5  213    Shuckle
# 231      500  80     125       75       40       95     85  214  Heracross
#
#     Type 1    Type 2  Generation  Legendary
# 230    Bug      Rock           2      False
# 231    Bug  Fighting           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 232      600  80     185      115       40      105     75  214
# 233      430  55      95       55       35       75    115  215
#
#                         Name Type 1    Type 2  Generation  Legendary
# 232  HeracrossMega Heracross    Bug  Fighting           2      False
# 233                  Sneasel   Dark       Ice           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 234      330  60      80       50       50       50     40  216  Teddiursa
# 235      500  90     130       75       75       75     55  217   Ursaring
#
#      Type 1  Type 2  Generation  Legendary
# 234  Normal     NaN           2      False
# 235  Normal     NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 236      250  40      40       40       70       40     20  218    Slugma
# 237      410  50      50      120       80       80     30  219  Magcargo
#
#     Type 1 Type 2  Generation  Legendary
# 236   Fire    NaN           2      False
# 237   Fire   Rock           2      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 238      250   50      50       40       30       30     50  220     Swinub
# 239      450  100     100       80       60       60     50  221  Piloswine
#
#     Type 1  Type 2  Generation  Legendary
# 238    Ice  Ground           2      False
# 239    Ice  Ground           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 240      380  55      55       85       65       85     35  222   Corsola
# 241      300  35      65       35       65       35     65  223  Remoraid
#
#     Type 1 Type 2  Generation  Legendary
# 240  Water   Rock           2      False
# 241  Water    NaN           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 242      480  75     105       75      105       75     45  224  Octillery
# 243      330  45      55       45       65       45     75  225   Delibird
#
#     Type 1  Type 2  Generation  Legendary
# 242  Water     NaN           2      False
# 243    Ice  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 244      465  65      40       70       80      140     70  226   Mantine
# 245      465  65      80      140       40       70     70  227  Skarmory
#
#     Type 1  Type 2  Generation  Legendary
# 244  Water  Flying           2      False
# 245  Steel  Flying           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 246      330  45      60       30       80       50     65  228  Houndour
# 247      500  75      90       50      110       80     95  229  Houndoom
#
#     Type 1 Type 2  Generation  Legendary
# 246   Dark   Fire           2      False
# 247   Dark   Fire           2      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 248      600  75      90       90      140       90    115  229
# 249      540  75      95       95       95       95     85  230
#
#                       Name Type 1  Type 2  Generation  Legendary
# ...
# 717                 Genesect     Bug     Steel           5      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 718      313  56      61       65       48       45     38  650    Chespin
# 719      405  61      78       95       56       58     57  651  Quilladin
#
#     Type 1  Type 2  Generation  Legendary
# 718  Grass     NaN           6      False
# 719  Grass     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 720      530  88     107      122       74       75     64  652  Chesnaught
# 721      307  40      45       40       62       60     60  653    Fennekin
#
#     Type 1    Type 2  Generation  Legendary
# 720  Grass  Fighting           6      False
# 721   Fire       NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 722      409  59      59       58       90       70     73  654  Braixen
# 723      534  75      69       72      114      100    104  655  Delphox
#
#     Type 1   Type 2  Generation  Legendary
# 722   Fire      NaN           6      False
# 723   Fire  Psychic           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 724      314  41      56       40       62       44     71  656    Froakie
# 725      405  54      63       52       83       56     97  657  Frogadier
#
#     Type 1  Type 2  Generation  Legendary
# 724  Water     NaN           6      False
# 725  Water     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 726      530  72      95       67      103       71    122  658  Greninja
# 727      237  38      36       38       32       36     57  659  Bunnelby
#
#      Type 1 Type 2  Generation  Legendary
# 726   Water   Dark           6      False
# 727  Normal    NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 728      423  85      56       77       50       77     78  660   Diggersby
# 729      278  45      50       43       40       38     62  661  Fletchling
#
#      Type 1  Type 2  Generation  Legendary
# 728  Normal  Ground           6      False
# 729  Normal  Flying           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #         Name  \
# 730      382  62      73       55       56       52     84  662  Fletchinder
# 731      499  78      81       71       74       69    126  663   Talonflame
#
#     Type 1  Type 2  Generation  Legendary
# 730   Fire  Flying           6      False
# 731   Fire  Flying           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 732      200  38      35       40       27       25     35  664  Scatterbug
# 733      213  45      22       60       27       30     29  665      Spewpa
#
#     Type 1  Type 2  Generation  Legendary
# 732    Bug     NaN           6      False
# 733    Bug     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 734      411  80      52       50       90       50     89  666  Vivillon
# 735      369  62      50       58       73       54     72  667    Litleo
#
#     Type 1  Type 2  Generation  Legendary
# 734    Bug  Flying           6      False
# 735   Fire  Normal           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 736      507  86      68       72      109       66    106  668   Pyroar
# 737      303  44      38       39       61       79     42  669  Flabébé
#
#     Type 1  Type 2  Generation  Legendary
# 736   Fire  Normal           6      False
# 737  Fairy     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 738      371  54      45       47       75       98     52  670  Floette
# 739      552  78      65       68      112      154     75  671  Florges
#
#     Type 1  Type 2  Generation  Legendary
# 738  Fairy     NaN           6      False
# 739  Fairy     NaN           6      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 740      350   66      65       48       62       57     52  672  Skiddo
# 741      531  123     100       62       97       81     68  673  Gogoat
#
#     Type 1  Type 2  Generation  Legendary
# 740  Grass     NaN           6      False
# 741  Grass     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 742      348  67      82       62       46       48     43  674  Pancham
# 743      495  95     124       78       69       71     58  675  Pangoro
#
#        Type 1 Type 2  Generation  Legendary
# 742  Fighting    NaN           6      False
# 743  Fighting   Dark           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 744      472  75      80       60       65       90    102  676  Furfrou
# 745      355  62      48       54       63       60     68  677   Espurr
#
#       Type 1  Type 2  Generation  Legendary
# 744   Normal     NaN           6      False
# 745  Psychic     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 746      466  74      48       76       83       81    104  678
# 747      466  74      48       76       83       81    104  678
#
#                Name   Type 1  Type 2  Generation  Legendary
# 746    MeowsticMale  Psychic     NaN           6      False
# 747  MeowsticFemale  Psychic     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 748      325  45      80      100       35       37     28  679   Honedge
# 749      448  59     110      150       45       49     35  680  Doublade
#
#     Type 1 Type 2  Generation  Legendary
# 748  Steel  Ghost           6      False
# 749  Steel  Ghost           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 750      520  60     150       50      150       50     60  681
# 751      520  60      50      150       50      150     60  681
#
#                       Name Type 1 Type 2  Generation  Legendary
# 750   AegislashBlade Forme  Steel  Ghost           6      False
# 751  AegislashShield Forme  Steel  Ghost           6      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 752      341   78      52       60       63       65     23  682    Spritzee
# 753      462  101      72       72       99       89     29  683  Aromatisse
#
#     Type 1  Type 2  Generation  Legendary
# 752  Fairy     NaN           6      False
# 753  Fairy     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 754      341  62      48       66       59       57     49  684   Swirlix
# 755      480  82      80       86       85       75     72  685  Slurpuff
#
#     Type 1  Type 2  Generation  Legendary
# 754  Fairy     NaN           6      False
# 755  Fairy     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 756      288  53      54       53       37       46     45  686    Inkay
# 757      482  86      92       88       68       75     73  687  Malamar
#
#     Type 1   Type 2  Generation  Legendary
# 756   Dark  Psychic           6      False
# 757   Dark  Psychic           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 758      306  42      52       67       39       56     50  688     Binacle
# 759      500  72     105      115       54       86     68  689  Barbaracle
#
#     Type 1 Type 2  Generation  Legendary
# 758   Rock  Water           6      False
# 759   Rock  Water           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 760      320  50      60       60       60       60     30  690    Skrelp
# 761      494  65      75       90       97      123     44  691  Dragalge
#
#      Type 1  Type 2  Generation  Legendary
# 760  Poison   Water           6      False
# 761  Poison  Dragon           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 762      330  50      53       62       58       63     44  692  Clauncher
# 763      500  71      73       88      120       89     59  693  Clawitzer
#
#     Type 1  Type 2  Generation  Legendary
# 762  Water     NaN           6      False
# 763  Water     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #        Name  \
# 764      289  44      38       33       61       43     70  694  Helioptile
# 765      481  62      55       52      109       94    109  695   Heliolisk
#
#        Type 1  Type 2  Generation  Legendary
# 764  Electric  Normal           6      False
# 765  Electric  Normal           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 766      362  58      89       77       45       45     48  696     Tyrunt
# 767      521  82     121      119       69       59     71  697  Tyrantrum
#
#     Type 1  Type 2  Generation  Legendary
# 766   Rock  Dragon           6      False
# 767   Rock  Dragon           6      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 768      362   77      59       50       67       63     46  698   Amaura
# 769      521  123      77       72       99       92     58  699  Aurorus
#
#     Type 1 Type 2  Generation  Legendary
# 768   Rock    Ice           6      False
# 769   Rock    Ice           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 770      525  95      65       65      110      130     60  700   Sylveon
# 771      500  78      92       75       74       63    118  701  Hawlucha
#
#        Type 1  Type 2  Generation  Legendary
# 770     Fairy     NaN           6      False
# 771  Fighting  Flying           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 772      431  67      58       57       81       67    101  702  Dedenne
# 773      500  50      50      150       50      150     50  703  Carbink
#
#        Type 1 Type 2  Generation  Legendary
# 772  Electric  Fairy           6      False
# 773      Rock  Fairy           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 774      300  45      50       35       55       75     40  704    Goomy
# 775      452  68      75       53       83      113     60  705  Sliggoo
#
#      Type 1  Type 2  Generation  Legendary
# 774  Dragon     NaN           6      False
# 775  Dragon     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #    Name  \
# 776      600  90     100       70      110      150     80  706  Goodra
# 777      470  57      80       91       80       87     75  707  Klefki
#
#      Type 1 Type 2  Generation  Legendary
# 776  Dragon    NaN           6      False
# 777   Steel  Fairy           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #       Name  \
# 778      309  43      70       48       50       60     38  708   Phantump
# 779      474  85     110       76       65       82     56  709  Trevenant
#
#     Type 1 Type 2  Generation  Legendary
# 778  Ghost  Grass           6      False
# 779  Ghost  Grass           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 780      335  49      66       70       44       55     51  710
# 781      335  44      66       70       44       55     56  710
#
#                       Name Type 1 Type 2  Generation  Legendary
# 780  PumpkabooAverage Size  Ghost  Grass           6      False
# 781    PumpkabooSmall Size  Ghost  Grass           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 782      335  54      66       70       44       55     46  710
# 783      335  59      66       70       44       55     41  710
#
#                     Name Type 1 Type 2  Generation  Legendary
# 782  PumpkabooLarge Size  Ghost  Grass           6      False
# 783  PumpkabooSuper Size  Ghost  Grass           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 784      494  65      90      122       58       75     84  711
# 785      494  55      85      122       58       75     99  711
#
#                       Name Type 1 Type 2  Generation  Legendary
# 784  GourgeistAverage Size  Ghost  Grass           6      False
# 785    GourgeistSmall Size  Ghost  Grass           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 786      494  75      95      122       58       75     69  711
# 787      494  85     100      122       58       75     54  711
#
#                     Name Type 1 Type 2  Generation  Legendary
# 786  GourgeistLarge Size  Ghost  Grass           6      False
# 787  GourgeistSuper Size  Ghost  Grass           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #      Name  \
# 788      304  55      69       85       32       35     28  712  Bergmite
# 789      514  95     117      184       44       46     28  713   Avalugg
#
#     Type 1  Type 2  Generation  Legendary
# 788    Ice     NaN           6      False
# 789    Ice     NaN           6      False
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 790      245  40      30       35       45       40     55  714   Noibat
# 791      535  85      70       80       97       80    123  715  Noivern
#
#      Type 1  Type 2  Generation  Legendary
# 790  Flying  Dragon           6      False
# 791  Flying  Dragon           6      False
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #     Name  \
# 792      680  126     131       95      131       98     99  716  Xerneas
# 793      680  126     131       95      131       98     99  717  Yveltal
#
#     Type 1  Type 2  Generation  Legendary
# 792  Fairy     NaN           6       True
# 793   Dark  Flying           6       True
# Current Batch:
#      Totalv2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 794      600  108     100      121       81       95     95  718
# 795      600   50     100      150      100      150     50  719
#
#                  Name  Type 1  Type 2  Generation  Legendary
# 794  Zygarde50% Forme  Dragon  Ground           6       True
# 795           Diancie    Rock   Fairy           6       True
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 796      700  50     160      110      160      110    110  719
# 797      600  80     110       60      150      130     70  720
#
#                     Name   Type 1 Type 2  Generation  Legendary
# 796  DiancieMega Diancie     Rock  Fairy           6       True
# 797  HoopaHoopa Confined  Psychic  Ghost           6       True
# Current Batch:
#      Totalv2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed    #  \
# 798      680  80     160       60      170      130     80  720
# 799      600  80     110      120      130       90     70  721
#
#                    Name   Type 1 Type 2  Generation  Legendary
# 798  HoopaHoopa Unbound  Psychic   Dark           6       True
# 799           Volcanion     Fire  Water           6       True

# %% [markdown]
# New dataframe based on the aggregation of another dataframe

# %%
df_group = pd.DataFrame(columns=df.columns)

for df in pd.read_csv('modified_pokemon_df.csv', chunksize=10):
    batch = df.groupby('Type 1').count()
    df_group = pd.concat([df_group, batch])
df_group
# Out:
#         Totalv2 HP Attack Defense Sp. Atk Sp. Def Speed  # Name Type 1 Type 2  \
# Fire          5  5      5       5       5       5     5  5    5    NaN      3
# Grass         4  4      4       4       4       4     4  4    4    NaN      4
# Water         1  1      1       1       1       1     1  1    1    NaN      0
# Bug           7  7      7       7       7       7     7  7    7    NaN      5
# Water         3  3      3       3       3       3     3  3    3    NaN      0
# ...         ... ..    ...     ...     ...     ...   ... ..  ...    ...    ...
# Fairy         1  1      1       1       1       1     1  1    1    NaN      0
# Fire          1  1      1       1       1       1     1  1    1    NaN      1
# Flying        2  2      2       2       2       2     2  2    2    NaN      2
# Psychic       2  2      2       2       2       2     2  2    2    NaN      2
# Rock          2  2      2       2       2       2     2  2    2    NaN      2
#
#         Generation Legendary
# Fire             5         5
# Grass            4         4
# Water            1         1
# Bug              7         7
# Water            3         3
# ...            ...       ...
# Fairy            1         1
# Fire             1         1
# Flying           2         2
# Psychic          2         2
# Rock             2         2
#
# [361 rows x 13 columns]
